# %% [markdown]
# # Early Warning Models for Financial Crisis using Machine Learning Techniques

# %% [markdown]
# ### Yelebe Desta and Seth Tenberg

# %% [markdown]
# # Lit Review

# %%
# I fixed the global credit rate
# i changed the hyperparemeter tuning to get it to work
# random forest is okay!
# neural network performed really good, suspiciously too good but I'll have to double check work
# looking at out of sample performance neural network > lasso > logistic > random forest
#not sure why random forest sucked, also could not get my code to work for elastic net

# %% [markdown]
# # Cleaning the Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from keras.optimizers import Adam
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

set_seed(455)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-78120f106bcc> in <module>
#      21 from sklearn.preprocessing import MinMaxScaler
#      22 from sklearn.metrics import mean_squared_error
# ---> 23 import tensorflow as tf
#      24 from tensorflow.keras.models import Sequential
#      25 from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
data = pd.read_excel("/Users/yelebedesta/Downloads/JSTdatasetR6.xlsx")

# %% [markdown]
# # Exploring the Data

# %%
data.describe()
# Out:
#              year          ifs            pop       rgdpmad    rgdpbarro  \
# count  2718.00000  2718.000000    2667.000000   2666.000000  2664.000000
# mean   1945.00000   148.333333   31439.397574   9155.064763    39.793748
# std      43.59701    24.165940   45898.993728   7976.190143    33.884462
# min    1870.00000   111.000000    1675.000000    737.375497     3.263085
# 25%    1907.00000   132.000000    4866.650000   2873.047663    12.694448
# 50%    1945.00000   143.000000   10113.530000   5477.011227    23.056114
# 75%    1983.00000   172.000000   45077.000000  14619.435708    65.770534
# max    2020.00000   193.000000  329239.715278  45887.569802   147.282620
#
#         rconsbarro           gdp           iy           cpi            ca  \
# count  2561.000000  2.641000e+03  2425.000000  2.666000e+03  2.489000e+03
# mean     42.133609  2.454826e+06     0.188838  4.191118e+01 -4.572271e+04
# std      32.274402  1.615548e+07     0.064621  5.689962e+01  7.670287e+05
# min       4.074400  1.250757e-11     0.017287  1.150362e-11 -1.687900e+07
# 25%      15.650000  5.428200e+01     0.140980  2.526395e+00 -6.345947e+01
# 50%      27.846700  1.810926e+03     0.194356  1.050679e+01 -3.300000e-02
# 75%      68.720000  5.038345e+04     0.230288  7.617557e+01  1.788000e+01
# max     120.431162  2.070466e+08     0.546975  2.268252e+02  5.885998e+06
#
#        ...    eq_capgain        eq_dp  eq_capgain_interp  eq_tr_interp  \
# count  ...  2.170000e+03  2169.000000                7.0           7.0
# mean   ...  1.167935e+06     0.040949                1.0           1.0
# std    ...  5.440622e+07     0.017111                0.0           0.0
# min    ... -8.842261e-01     0.000000                1.0           1.0
# 25%    ... -5.496224e-02     0.030100                1.0           1.0
# 50%    ...  4.175594e-02     0.040665                1.0           1.0
# 75%    ...  1.568719e-01     0.051569                1.0           1.0
# max    ...  2.534419e+09     0.127113                1.0           1.0
#
#        eq_dp_interp    bond_rate   eq_div_rtn   capital_tr     risky_tr  \
# count           6.0  2381.000000  2163.000000  1830.000000  1854.000000
# mean            1.0     0.054346     0.042763     0.099308     0.111523
# std             0.0     0.031442     0.017694     0.090360     0.110373
# min             1.0    -0.035316     0.000000    -0.232140    -0.238515
# 25%             1.0     0.036000     0.032112     0.047950     0.051188
# 50%             1.0     0.046100     0.042530     0.090982     0.102568
# 75%             1.0     0.063500     0.053196     0.137372     0.159925
# max             1.0     0.237154     0.138189     1.144161     1.281639
#
#            safe_tr
# count  2247.000000
# mean      0.051634
# std       0.048357
# min      -0.152371
# 25%       0.024857
# 50%       0.043005
# 75%       0.067896
# max       0.408514
#
# [8 rows x 55 columns]

# %% [markdown]
# We want to make a early warning indicator model, thus our dependent variable of interest is not when the crisis occurs, but a year or two *before* the crisis occurs. The dataset being used encodes the year that a crisis occurs; we can do a quick fix to create our binary dependent variable.

# %%
data['indicator'] = ((data['crisisJST'].shift(-1) == 1) | (data['crisisJST'].shift(-2) == 1)).astype(int)

# %% [markdown]
# Now we will remove the year of the crisis along with the following four years to remove post crisis bias, which has been shown to affect analysis in previous research.

# %%
crisis_rows = data[data['crisisJST'] == 1].index.tolist()
crisis_rows_incremented1 = [row + 1 for row in crisis_rows]
crisis_rows_incremented2 = [row + 2 for row in crisis_rows]
crisis_rows_incremented3 = [row + 3 for row in crisis_rows]
crisis_rows_incremented4 = [row + 4 for row in crisis_rows]

crisis_rows_df = pd.DataFrame(
    {'crisis_rows': crisis_rows,
     'crisis_rows_incremented1': crisis_rows_incremented1,
     'crisis_rows_incremented2': crisis_rows_incremented2,
     'crisis_rows_incremented3': crisis_rows_incremented3,
     'crisis_rows_incremented4': crisis_rows_incremented4})

rows_to_remove = pd.concat([crisis_rows_df[col] for col in crisis_rows_df.columns])

# Sort the values in the combined column
rows_to_remove = rows_to_remove.sort_values()
# remove the rows from the data to account for crisis bias
data = data.drop(data.index[rows_to_remove])
# we have removed 435 from the dataset

# %% [markdown]
# Now we wil account for extraordinary events in history, and remove the years during which World War 1, the Great Depression, and World War 2. Then we will also create two new variables for our analysis. We create a measure of global credit creation, and a measure for the global slope of the yield curve.

# %%
# we will create a variable the measures the slope of the yield curve, subtracting short term interest rates from long term interest rates
data['slope'] = (data['ltrate'] - data['stir'])
# removing years for WW1, WW2, and Great Depression
data_filtered = data[(data['year'] < 1914) | (data['year'] > 1918)]
data = data_filtered[(data_filtered['year'] < 1933) | (data_filtered['year'] > 1945)]
data['year']
# now we will create our global slope and credit variables
grouped = data.groupby('year')
data = grouped.apply(lambda x: x.assign(
    global_slope=x.loc[x['country'] != x['country'].iloc[0], 'slope'].mean()
))

# Ungroup
data= data.reset_index(drop=True)

#making Debt Servicing Ratio Variable
data['DSR'] = (data['tloans'] - (data['ltrate']/data['gdp']))

# %% [markdown]
# To ensure stationarity of the time series data, we will augment most of our variables. CPI, Real Consumption per Capita, Housing prices, Money Supply, Credit Supply, Investment, and current account are all converted into growth rates ratios of GDP. We also change Stock prices, Debt/GDP ratio, and Debt Servicing Ratio are all changed into one year rates of change.

# %%
data_rate = data.groupby('country').apply(lambda group: 
    group.assign(
        cpi_rate = (group['cpi'] - group['cpi'].shift(1)) / group['cpi'].shift(1),
        rconsumption_rate = (group['rconsbarro'] - group['rconsbarro'].shift(1)) / group['rconsbarro'].shift(1),
        housing_rate = (group['hpnom'] - group['hpnom'].shift(1)) / group['hpnom'].shift(1),
        money_rate = (group['money'] - group['money'].shift(1)) / group['money'].shift(1),
        DSR_rate = (group['DSR'] - group['DSR'].shift(1)/ group['DSR'].shift(1)),
        credit_rate = (group['tloans'] / group['gdp'] - group['tloans'].shift(1) / group['gdp'].shift(1)),
        ca_rate = (group['ca'] / group['gdp'] - group['ca'].shift(1) / group['gdp'].shift(1)),
        investment_rate = (group['iy'] - group['iy'].shift(1)),
        stock_rate =  ((group['capital_tr'] - group['capital_tr'].shift(1))/group['capital_tr'].shift(1)),
        debtgdp_rate = (group['debtgdp'] - group['debtgdp'].shift(1))
    )
).reset_index(drop=True)

grouped = data_rate.groupby('year')
data_rate = grouped.apply(lambda x: x.assign(
    global_credit_rate=x.loc[x['country'] != x['country'].iloc[0], 'credit_rate'].mean()
))

# Ungroup
data_rate= data_rate.reset_index(drop=True)

# %%
columns_to_keep = ['cpi_rate', 'rconsumption_rate', 'housing_rate', 'money_rate', 'DSR_rate', 'credit_rate', 
                   'global_credit_rate', 'slope', 'global_slope','ca_rate',  'investment_rate',  'debtgdp_rate', 'noncore', 'lev', 'stock_rate', 'indicator']
data_subset = data_rate[columns_to_keep]

missing_rows = data_subset[data_subset.isnull().any(axis=1)]

# Print the number of rows with missing values
print("Number of rows with missing values:", len(missing_rows))
# Out:
# Number of rows with missing values: 950

# %%
# dropping all the rows with na's 
data_subset = data_subset.dropna()

# %%
# standardizing the data
X = data_subset.drop(columns=['indicator'])
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform the data
X_standardized = scaler.fit_transform(X)

# Convert the standardized array back to a DataFrame with column names
X_standardized = pd.DataFrame(X_standardized, columns=X.columns)
X_standardized.head()
y = data_subset['indicator']

# %%
X_standardized = X_standardized.rename(columns={'cpi_rate' : 'CPI Rate', 'rconsumption_rate' : 'Consumption Rate', 'housing_rate' : 'Housing Rate', 'money_rate' : 'Money Rate', 'DSR_rate' : 'DSR Rate',
                      'credit_rate' : 'Credit Rate', 'ca_rate' : 'CA Rate', 'investment_rate' : 'Investment Rate', 'stock_rate' : 'Stock Rate', 'debtgdp_rate' : 'Debt/GDP Rate',
                      'slope' : 'Slope', 'global_slope': 'Global Slope', 'global_credit_rate' : 'Global Credit Rate','lev' : 'Leverage', 'noncore' : 'Noncore'})
X_standardized.head()
# Out:
#    CPI Rate  Consumption Rate  Housing Rate  Money Rate  DSR Rate  \
# 0 -0.693408          1.864756     -1.275990    0.231615 -9.778837
# 1 -0.628167         -1.128992     -0.490031   -0.332053 -9.585064
# 2 -0.018496         -1.904651     -0.963588   -0.393191 -9.119077
# 3 -0.550691         -0.075347      0.484254   -0.075021 -8.735787
# 4 -0.328181         -0.848215     -0.718369   -0.379161 -8.484894
#
#    Credit Rate  Global Credit Rate     Slope  Global Slope   CA Rate  \
# 0     0.372668            1.005284 -0.597750      1.450215  0.456868
# 1     0.048102            0.004677 -0.071031      0.644050 -0.212679
# 2     0.106450           -0.270389 -0.073989      0.329605 -0.121950
# 3     0.135958           -0.037074 -0.562761     -0.955485  0.137506
# 4    -0.075804            0.601846 -0.428930     -1.047246  0.200049
#
#    Investment Rate  Debt/GDP Rate   Noncore  Leverage  Stock Rate
# 0        -3.188685       0.643158 -0.222619  2.643800   -0.200080
# 1        -1.712066       0.643158 -0.214396  2.510223    0.056496
# 2         0.356741       0.356230 -0.222666  2.504618   -0.055120
# 3         0.761094       0.069302 -0.204620  2.539417    0.002899
# 4        -0.251029       0.212766 -0.219478  2.508932   -0.059165

# %%
# Calculate correlation matrix
correlation_matrix = X_standardized.corr()

# Create Seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Plot (Selected Variables)')
plt.show()

# %% [markdown]
# While most variables are uncorrelated with one another, a few variables do have moderately strong relationships with our other explanatory variables. The CPI rate and the money supply growth rate have a very strong correlation (0.79). Noticably, the global and domestic slope variables have a correlation around 0.5. Our global and domestic variables appear to measure different things and are not highly correlated alternatives.

# %% [markdown]
# # Basic Logistic Model
#
# To begin the analysis, we will construct a logistic model with all the variables included. This will serve as a baseline to reference for model performance. For analyze out-of-sample predictive performance, we will use a k-fold-crossfold validation method. Given the limited number of financial crises, splitting the data into a training and testing set would reduce predictive capabilities of the models. Previous research has shown that the two methods will perform comparably. We will use multiple methods to compare model performance. These methods include examining the *Receiver Operating Characteristic* space, Recall rate, and Shapley Values. These methods will be discussed later on.

# %% [markdown]
# We will now create the models that will be used for predicting financial crises. We will investigate the variables of importance and see if there are any variables that are consistantly important across all the models. Then the models will be tested for predictive performance.

# %%
X_standardized['intercept']=1.0
#y #1057
#X_standardized #1057
y = list(y)
logit = sm.Logit(y, X_standardized)
logit_fit=logit.fit()


logit_fit.summary()
coeff = logit_fit.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.205376
#          Iterations 9

# %%
coefficients = logit_fit.params
coefficients = coefficients.drop(['intercept'])
coef_names = coefficients.index

sorted_coefficients = sorted(zip(coefficients, coef_names), reverse=True)
sorted_coefficients, sorted_coef_names = zip(*sorted_coefficients)

cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
plt.barh(sorted_coef_names, sorted_coefficients, color=cmap(abs(coefficients) / max(abs(coefficients))))

plt.xlabel('Variable')
plt.ylabel('Coefficient')
plt.title('Coefficients Plot for Logistic Model')
plt.xticks(rotation=90)
plt.show()

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

# %% [markdown]
# This chart illustrates the most important feautures in our logistic model. As seen above, the most important features are The global and domestic credit growth rates, the global and domestic yield curve slopes, noncore funding, and money supply growth.

# %% [markdown]
# # Lasso Model

# %% [markdown]
# We will now implement penalized logistic models. First we create a Lasso logistic model and tune the model using cross-validation to find a good value for the penalty term. Then the coefficients are plotted from the model using the *good* penalty term.

# %%
from sklearn.model_selection import cross_val_score

alpha_values = [0.0001, 0.001,0.005, 0.01, 0.1, 0.5, 1]
best_alpha = None
best_mse = float('inf')

cv_scores = {}

# Perform manual grid search with cross-validation
for alpha in alpha_values:
    lasso = Lasso(alpha=alpha)
    scores = cross_val_score(lasso, X_standardized, y, cv=5, scoring='neg_mean_squared_error')
    cv_scores[alpha] = np.mean(scores)

# Find the alpha with the best mean cross-validation score
best_alpha = min(cv_scores, key=cv_scores.get)
best_mse = -cv_scores[best_alpha]

print("Best Alpha:", best_alpha)
print("Best Cross-Validation MSE:", best_mse)
# Out:
# Best Alpha: 0.005
# Best Cross-Validation MSE: 0.07207463819144608

# %%
from sklearn.linear_model import LinearRegression, Lasso
# model evaluation
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV


lasso_best = Lasso(alpha=best_alpha)
lasso_best.fit(X_standardized, y)


coeff_lasso = lasso_best.coef_
columns = ['Lasso_Coefficient', 'Feature']
new_df = pd.DataFrame(X_standardized.columns,coeff_lasso)





data = {'coeff_lasso': coeff_lasso, 'column_names': X_standardized.columns}

# Create DataFrame
df = pd.DataFrame(data)

df = df.drop(df.index[-1])

df = df.sort_values(by = 'coeff_lasso', ascending = False)

#new_df.drop(new_df.index[-1], inplace = True)


#columns = ['Lasso_Coefficient', 'Feature']
#new_df = pd.DataFrame(new_df, columns = columns)

plt.figure(figsize = (10,6))
plt.barh(df['column_names'], df['coeff_lasso'])
plt.xlabel('Variable')
plt.ylabel('Coefficient')
plt.title('Coefficients Plot for Lasso Model')

#new_df

#feature_importance_Lasso = lasso_best.feature_importances_

#feature_importance = pd.DataFrame({'Feature': X_standardized.columns, 'Importance': np.abs(coefficients)})
#feature_importance = feature_importance.sort_values('Importance', ascending=True)
#feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
# Out:
# Text(0.5, 1.0, 'Coefficients Plot for Lasso Model')

# %%
column_names = df['column_names']
coeff_lasso = df['coeff_lasso']

# Define colormap 'viridis'
cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
bars = plt.barh(column_names, coeff_lasso, color=cmap(abs(coeff_lasso) / max(abs(coeff_lasso))))
plt.xlabel('Variable')
plt.ylabel('Coefficients')
plt.title('Coefficients Plot for Lasso Model')

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([0.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

plt.show()

# %% [markdown]
# Negative values of global and domestic yield curve slope, and stocks all remain important for predicting financial crisis. Alternatively, positive values for global and domestic credit growth, along with the leverage ratio and noncore funding all remain important for predicting financial crises. Noticably, quite a few variables are not important at all for the Lasso Model

# %% [markdown]
# # Elastic Net Model

# %% [markdown]
# The Elastic Net model combines the techniques of Lasso and Ridge models. We follow the same procedure from above, and also tune the hyperparameter l1 ratio, which controls how similiar the model is to Ridge versus Lasso. The coefficients from the model are then plotted

# %%
l1_ratio_values = [0.1, 0.3, 0.5, 0.7, 0.9]
alpha_values = [  0.0001, 0.001,0.005, 0.01, 0.1, 0.5, 1]

cv_scores = {}

# Perform manual grid search with cross-validation
for alpha in alpha_values:
    for l1_ratio in l1_ratio_values:
        elastic_net = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
        scores = cross_val_score(elastic_net, X_standardized, y, cv=5, scoring='neg_mean_squared_error')
        cv_scores[(alpha, l1_ratio)] = np.mean(scores)

# Find the alpha and l1_ratio with the best mean cross-validation score
best_hyperparams = min(cv_scores, key=cv_scores.get)
best_alpha1, best_l1_ratio = best_hyperparams
best_mse = -cv_scores[best_hyperparams]

print("Best Alpha:", best_alpha1)
print("Best l1_ratio:", best_l1_ratio)
print("Best Cross-Validation MSE:", best_mse)
# Out:
# Best Alpha: 0.0001
# Best l1_ratio: 0.1
# Best Cross-Validation MSE: 0.07312905314092481

# %%
elastic_net = ElasticNet()


elastic_net_best = ElasticNet(alpha = best_alpha, l1_ratio = best_l1_ratio)
elastic_net_best.fit(X_standardized, y)


coeff_elastic_net = elastic_net_best.coef_
columns = ['Elastic_Net_Coefficient', 'Feature']
new_df = pd.DataFrame(X_standardized.columns,coeff_elastic_net)


data = {'coeff_elastic_net': coeff_elastic_net, 'column_names': X_standardized.columns}

# Create DataFrame
df = pd.DataFrame(data)

df = df.drop(df.index[-1])

df = df.sort_values(by = 'coeff_elastic_net', ascending = False)

#new_df.drop(new_df.index[-1], inplace = True)


#columns = ['Lasso_Coefficient', 'Feature']
#new_df = pd.DataFrame(new_df, columns = columns)

plt.figure(figsize = (10,6))
plt.barh(df['column_names'], df['coeff_elastic_net'])
plt.xlabel('Variable')
plt.ylabel('Coefficients')
plt.title('Coefficients Plot for Elastic Net Model')
# Out:
# Text(0.5, 1.0, 'Coefficients Plot for Elastic Net Model')

# %%
column_names = df['column_names']
coeff_elastic_net = df['coeff_elastic_net']

# Define colormap 'viridis'
cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
bars = plt.barh(column_names, coeff_elastic_net, color=cmap(abs(coeff_elastic_net) / max(abs(coeff_elastic_net))))
plt.xlabel('Variable')
plt.ylabel('Coefficients')
plt.title('Coefficients Plot for Elastic Net Model')

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([0.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

plt.show()

# %% [markdown]
# Once again we see negative values of global and domestic slope along with consumption and stocks are important for predicting crisis. Similarly, positive values of global an domestic credit growth, along with the leverage ratio and noncore funding are important for the Elastic Net model

# %% [markdown]
# # Random Forest

# %%
forest = RandomForestRegressor()


param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': [3, 4, 5]
}
grid_search = GridSearchCV(estimator = forest, param_grid=param_grid, cv=5)
grid_search.fit(X_standardized, y)

best_n_estimators = grid_search.best_params_['n_estimators']
best_max_features = grid_search.best_params_['max_features']

forest_best = RandomForestClassifier(n_estimators = best_n_estimators, max_features = best_max_features)
forest_best.fit(X_standardized, y)
# Out:
# RandomForestClassifier(max_features=3)

# %%
Importance = pd.DataFrame({'Importance':forest_best.feature_importances_*100}, index=X_standardized.columns)
Importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r', figsize = (10,6))
plt.xlabel('Variable Importance')
plt.title('Feature Importance Plot for Random Forest Model')
plt.gca().legend_ = None

# %% [markdown]
# The most important features for the Random Forest model include the global and domestic variables of yield curve slope and credit growth. Stock prices and the leverage ratio are also important for the Random Forest model.

# %% [markdown]
# # Gradient Boosted Forests

# %%
gbm = GradientBoostingRegressor()

param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.05, 0.1, 0.2]
}

grid_search = GridSearchCV(estimator=gbm, param_grid=param_grid, cv=5)
grid_search.fit(X_standardized, y)

best_n_estimators = grid_search.best_params_['n_estimators']
best_max_depth = grid_search.best_params_['max_depth']
best_learning_rate = grid_search.best_params_['learning_rate']

gbm_best = GradientBoostingRegressor(n_estimators=best_n_estimators, max_depth=best_max_depth, learning_rate=best_learning_rate)
gbm_best.fit(X_standardized, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=5)

# %%
importance = pd.DataFrame({'Importance': gbm_best.feature_importances_ * 100}, index=X_standardized.columns)
importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r', figsize=(10, 6))
plt.xlabel('Variable Importance')
plt.title('Feature Importance Plot for Gradient Boosting Model')
plt.gca().legend_ = None
plt.show()

# %% [markdown]
# # Neural Networks

# %%
sorted_data_rate = data_rate.sort_values(by=['country', 'year'])
columns_to_keep = ['country', 'year' , 'credit_rate', 'global_credit_rate', 'slope', 'global_slope', 'noncore', 'indicator']
data_neural = sorted_data_rate[columns_to_keep]

missing_rows = data_neural[data_neural.isnull().any(axis=1)]

# dropping all the rows with na's 
data_neural = data_neural.dropna()

# standardizing the data
columns_to_standardize = ['credit_rate', 'global_credit_rate', 'slope', 'global_slope', 'noncore']
scaler = StandardScaler()
data_neural[columns_to_standardize] = scaler.fit_transform(data_neural[columns_to_standardize])
data_neural
# Out:
#         country  year  credit_rate  global_credit_rate     slope  \
# 16    Australia  1871    -0.336858            0.053235 -0.301009
# 31    Australia  1872    -0.340260            0.253581 -0.364700
# 46    Australia  1873    -0.192351           -0.162775 -0.284786
# 58    Australia  1874    -0.131585            0.436208 -0.355221
# 70    Australia  1875     0.116136            0.211913 -0.501262
# ...         ...   ...          ...                 ...       ...
# 1934        USA  2016     0.203446           -0.459909  0.415584
# 1952        USA  2017    -0.121957           -0.678443  0.343353
# 1970        USA  2018    -0.281685           -0.804327  0.194933
# 1988        USA  2019    -0.095976           -0.244561 -0.455642
# 2006        USA  2020     0.971311            2.064020 -0.135055
#
#       global_slope   noncore  indicator
# 16        0.400195 -0.367377          0
# 31       -0.369560 -0.534137          0
# 46        1.681109 -0.445387          0
# 58        2.021928 -0.462642          0
# 70        0.478685 -0.474990          0
# ...            ...       ...        ...
# 1934      0.255366 -1.099879          0
# 1952      0.501017 -1.114005          0
# 1970      0.390377 -1.134624          0
# 1988     -0.310664 -1.168274          0
# 2006     -0.527486 -1.324267          0
#
# [1516 rows x 8 columns]

# %%
train_data=data_neural.iloc[:int(len(data_neural)*0.7)] 
test_data=data_neural.iloc[int(len(data_neural)*0.7):]

# %%
train_data
# Out:
#         country  year  credit_rate  global_credit_rate     slope  \
# 16    Australia  1871    -0.336858            0.053235 -0.301009
# 31    Australia  1872    -0.340260            0.253581 -0.364700
# 46    Australia  1873    -0.192351           -0.162775 -0.284786
# 58    Australia  1874    -0.131585            0.436208 -0.355221
# 70    Australia  1875     0.116136            0.211913 -0.501262
# ...         ...   ...          ...                 ...       ...
# 1814   Portugal  2006     1.006817            1.239795  0.049941
# 1832   Portugal  2007     0.874177            1.372202 -0.359232
# 1875   Portugal  2013     0.332825           -0.681543  3.159478
# 1893   Portugal  2014    -2.295382           -1.013727  1.657900
# 1911   Portugal  2015    -1.905721           -1.147150  1.004317
#
#       global_slope   noncore  indicator
# 16        0.400195 -0.367377          0
# 31       -0.369560 -0.534137          0
# 46        1.681109 -0.445387          0
# 58        2.021928 -0.462642          0
# 70        0.478685 -0.474990          0
# ...            ...       ...        ...
# 1814     -0.245417  0.947451          1
# 1832     -0.610996  0.985248          1
# 1875      1.692743  0.907400          0
# 1893      1.080954  0.685829          0
# 1911      0.347039  0.335681          0
#
# [1061 rows x 8 columns]

# %%
usa = data_neural.country == "USA"
usa
# Out:
# 16      False
# 31      False
# 46      False
# 58      False
# 70      False
#         ...
# 1934     True
# 1952     True
# 1970     True
# 1988     True
# 2006     True
# Name: country, Length: 1516, dtype: bool

# %%
def train_test_split(data):
    size=int(len(data)*0.7)
    # for train data will be collected from each country's data which index is from 0-size (70%)
    x_train =data.drop(columns=['indicator']).iloc[0:size] 
    # for test data will be collected from each country's  data which index is from size to the end (30%)
    x_test = data.drop(columns=['indicator']).iloc[size:]
    y_train=data['indicator'].iloc[0:size] 
    y_test=data['indicator'].iloc[size:] 
    return x_train, x_test,y_train,y_test
# unique countries
country=list(set(data_neural.country))
# loop each country_Region and split the data into train and test data
X_train=[]
X_test=[]
Y_train=[]
Y_test=[]
for i in range(0,len(country)):
    df = data_neural[data_neural['country'] == country[i]]
    # applied the function I created above
    x_train, x_test,y_train,y_test=train_test_split(df)
    X_train.append(x_train)
    X_test.append(x_test)
    Y_train.append(y_train)
    Y_test.append(y_test)
# concatenate each train data n X_train list and Y_train list respectively
X_train=pd.concat(X_train)
Y_train=pd.DataFrame(pd.concat(Y_train))
# concatenate each test dataset in X_test list and Y_test list respectively
X_test=pd.concat(X_test)
Y_test=pd.DataFrame(pd.concat(Y_test))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def reshape_data(train,test):
    #Frame as supervised learning and drop all time t columns except
    reframed_train = series_to_supervised(train, 1, 1)
    reframed_test = series_to_supervised(test, 1, 1)
    # split into train and test sets
    train= reframed_train.values
    test=reframed_test.values
    # split into input and outputs
    train_X, y_train = train[:, :-1], train[:, -1]
    test_X, y_test = test[:, :-1], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    x_train = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    x_test = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    return x_train,x_test,y_train,y_test

# %%
encoder = LabelEncoder()
#combine X train and Y train as train data 
train_data=pd.DataFrame()
train_data[X_train.columns]=X_train
train_data[Y_train.columns]=Y_train
train_data['country']= encoder.fit_transform(train_data['country'])
#combine X test and Y test as test data 
test_data=pd.DataFrame()
test_data[X_test.columns]=X_test
test_data[Y_test.columns]=Y_test
test_data['country']= encoder.fit_transform(test_data['country'])
# using the function to obtian reshaped data 
x_train,x_test,y_train,y_test=reshape_data(train_data,test_data)
#take a look at the reshaped data!
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-f87220cc953d> in <module>
# ----> 1 encoder = LabelEncoder()
#       2 #combine X train and Y train as train data
#       3 train_data=pd.DataFrame()
#       4 train_data[X_train.columns]=X_train
#       5 train_data[Y_train.columns]=Y_train
#
# NameError: name 'LabelEncoder' is not defined

# %%
tf.random.set_seed(5)

# design network for confirmed cases data 
model = Sequential()
model.add(LSTM(60, activation='relu',input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam', metrics = ['AUC'] )
# fit network
history = model.fit(x_train, y_train, epochs=500, batch_size=300,  verbose=1, shuffle=False)
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - AUC: 0.5000 - loss: 2329.2502
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4931 - loss: 492.1620
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 69.3958
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 207.9983
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5000 - loss: 133.1165
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4990 - loss: 22.2589
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4487 - loss: 8.5458
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 33.9969
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 25.6118
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4745 - loss: 4.2335
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4736 - loss: 2.8785
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 8.5977
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5019 - loss: 5.3104
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4352 - loss: 1.0381
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4613 - loss: 1.7378
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4430 - loss: 2.1402
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4493 - loss: 0.8852
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4458 - loss: 0.7653
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4375 - loss: 1.1872
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4320 - loss: 0.9027
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4483 - loss: 0.6591
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4404 - loss: 0.7068
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4431 - loss: 0.6463
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.4538 - loss: 0.6088
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4503 - loss: 0.6663
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4538 - loss: 0.6565
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4556 - loss: 0.6155
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4564 - loss: 0.6027
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4568 - loss: 0.5922
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4583 - loss: 0.5932
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4581 - loss: 0.6015
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4604 - loss: 0.5961
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4612 - loss: 0.5849
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4632 - loss: 0.5771
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4617 - loss: 0.5732
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.4606 - loss: 0.5728
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4612 - loss: 0.5709
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4670 - loss: 0.5654
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4668 - loss: 0.5593
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4667 - loss: 0.5546
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4675 - loss: 0.5516
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4678 - loss: 0.5485
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4680 - loss: 0.5443
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4682 - loss: 0.5394
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4691 - loss: 0.5349
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4696 - loss: 0.5311
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4702 - loss: 0.5274
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4710 - loss: 0.5233
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4717 - loss: 0.5189
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4725 - loss: 0.5146
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4750 - loss: 0.5106
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4759 - loss: 0.5066
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4764 - loss: 0.5025
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4772 - loss: 0.4982
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4777 - loss: 0.4941
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4784 - loss: 0.4900
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4792 - loss: 0.4860
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4803 - loss: 0.4819
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4811 - loss: 0.4778
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.4816 - loss: 0.4737
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4819 - loss: 0.4697
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4827 - loss: 0.4657
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4836 - loss: 0.4617
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4843 - loss: 0.4577
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4847 - loss: 0.4537
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4857 - loss: 0.4497
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4862 - loss: 0.4458
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4863 - loss: 0.4419
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4869 - loss: 0.4380
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4873 - loss: 0.4341
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4876 - loss: 0.4302
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4880 - loss: 0.4263
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4885 - loss: 0.4225
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4889 - loss: 0.4187
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4896 - loss: 0.4149
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4901 - loss: 0.4111
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4907 - loss: 0.4074
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4914 - loss: 0.4037
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4918 - loss: 0.4000
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4922 - loss: 0.3963
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4940 - loss: 0.3926
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4947 - loss: 0.3890
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4954 - loss: 0.3854
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4960 - loss: 0.3818
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4966 - loss: 0.3782
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4972 - loss: 0.3747
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4975 - loss: 0.3711
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4979 - loss: 0.3676
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4982 - loss: 0.3642
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4988 - loss: 0.3607
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.4993 - loss: 0.3573
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5000 - loss: 0.3539
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5009 - loss: 0.3505
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5012 - loss: 0.3472
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5017 - loss: 0.3438
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5023 - loss: 0.3405
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5044 - loss: 0.3373
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5049 - loss: 0.3340
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5054 - loss: 0.3308
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.5054 - loss: 0.3276
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5061 - loss: 0.3244
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5078 - loss: 0.3213
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5082 - loss: 0.3181
# Epoch 104/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5090 - loss: 0.3150
# Epoch 105/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5093 - loss: 0.3120
# Epoch 106/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5101 - loss: 0.3089
# Epoch 107/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5108 - loss: 0.3059
# Epoch 108/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5112 - loss: 0.3029
# Epoch 109/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5120 - loss: 0.2999
# Epoch 110/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5112 - loss: 0.2970
# Epoch 111/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5118 - loss: 0.2941
# Epoch 112/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5121 - loss: 0.2912
# Epoch 113/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5127 - loss: 0.2883
# Epoch 114/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5134 - loss: 0.2855
# Epoch 115/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5131 - loss: 0.2826
# Epoch 116/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5140 - loss: 0.2798
# Epoch 117/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5145 - loss: 0.2771
# Epoch 118/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5149 - loss: 0.2743
# Epoch 119/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5157 - loss: 0.2716
# Epoch 120/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.5163 - loss: 0.2689
# Epoch 121/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5172 - loss: 0.2662
# Epoch 122/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5177 - loss: 0.2636
# Epoch 123/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5186 - loss: 0.2610
# Epoch 124/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5193 - loss: 0.2584
# Epoch 125/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5195 - loss: 0.2558
# Epoch 126/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5201 - loss: 0.2533
# Epoch 127/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5203 - loss: 0.2507
# Epoch 128/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5209 - loss: 0.2482
# Epoch 129/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5214 - loss: 0.2458
# Epoch 130/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5229 - loss: 0.2433
# Epoch 131/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5242 - loss: 0.2409
# Epoch 132/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5253 - loss: 0.2385
# Epoch 133/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5259 - loss: 0.2361
# Epoch 134/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5259 - loss: 0.2338
# Epoch 135/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5265 - loss: 0.2314
# Epoch 136/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5273 - loss: 0.2291
# Epoch 137/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5276 - loss: 0.2269
# Epoch 138/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5282 - loss: 0.2246
# Epoch 139/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5338 - loss: 0.2224
# Epoch 140/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5343 - loss: 0.2202
# Epoch 141/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5359 - loss: 0.2180
# Epoch 142/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5361 - loss: 0.2158
# Epoch 143/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5372 - loss: 0.2137
# Epoch 144/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5376 - loss: 0.2115
# Epoch 145/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5385 - loss: 0.2094
# Epoch 146/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5388 - loss: 0.2074
# Epoch 147/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5397 - loss: 0.2053
# Epoch 148/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5404 - loss: 0.2033
# Epoch 149/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5410 - loss: 0.2013
# Epoch 150/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5415 - loss: 0.1993
# Epoch 151/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5420 - loss: 0.1973
# Epoch 152/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5427 - loss: 0.1954
# Epoch 153/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5434 - loss: 0.1935
# Epoch 154/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.5441 - loss: 0.1916
# Epoch 155/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5449 - loss: 0.1897
# Epoch 156/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5458 - loss: 0.1879
# Epoch 157/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5517 - loss: 0.1860
# Epoch 158/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5523 - loss: 0.1842
# Epoch 159/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5526 - loss: 0.1824
# Epoch 160/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5537 - loss: 0.1806
# Epoch 161/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5543 - loss: 0.1789
# Epoch 162/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5543 - loss: 0.1772
# Epoch 163/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5552 - loss: 0.1755
# Epoch 164/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5555 - loss: 0.1738
# Epoch 165/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5563 - loss: 0.1721
# Epoch 166/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5568 - loss: 0.1705
# Epoch 167/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5582 - loss: 0.1688
# Epoch 168/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5583 - loss: 0.1672
# Epoch 169/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.5589 - loss: 0.1656
# Epoch 170/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5594 - loss: 0.1641
# Epoch 171/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5599 - loss: 0.1625
# Epoch 172/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5624 - loss: 0.1610
# Epoch 173/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5632 - loss: 0.1595
# Epoch 174/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5647 - loss: 0.1580
# Epoch 175/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5656 - loss: 0.1565
# Epoch 176/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5668 - loss: 0.1550
# Epoch 177/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5725 - loss: 0.1536
# Epoch 178/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5730 - loss: 0.1522
# Epoch 179/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5739 - loss: 0.1508
# Epoch 180/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5746 - loss: 0.1494
# Epoch 181/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5753 - loss: 0.1480
# Epoch 182/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5823 - loss: 0.1467
# Epoch 183/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5834 - loss: 0.1454
# Epoch 184/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5840 - loss: 0.1441
# Epoch 185/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5847 - loss: 0.1428
# Epoch 186/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5852 - loss: 0.1415
# Epoch 187/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5861 - loss: 0.1402
# Epoch 188/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5898 - loss: 0.1390
# Epoch 189/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5935 - loss: 0.1377
# Epoch 190/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.5938 - loss: 0.1365
# Epoch 191/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.5994 - loss: 0.1353
# Epoch 192/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6004 - loss: 0.1342
# Epoch 193/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6014 - loss: 0.1330
# Epoch 194/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6028 - loss: 0.1318
# Epoch 195/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6027 - loss: 0.1307
# Epoch 196/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6065 - loss: 0.1296
# Epoch 197/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.6133 - loss: 0.1285
# Epoch 198/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.6140 - loss: 0.1274
# Epoch 199/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6206 - loss: 0.1263
# Epoch 200/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6263 - loss: 0.1253
# Epoch 201/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6270 - loss: 0.1243
# Epoch 202/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6281 - loss: 0.1232
# Epoch 203/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6288 - loss: 0.1222
# Epoch 204/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6300 - loss: 0.1212
# Epoch 205/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6309 - loss: 0.1202
# Epoch 206/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6318 - loss: 0.1193
# Epoch 207/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6331 - loss: 0.1183
# Epoch 208/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6342 - loss: 0.1174
# Epoch 209/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6353 - loss: 0.1164
# Epoch 210/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6360 - loss: 0.1155
# Epoch 211/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.6370 - loss: 0.1146
# Epoch 212/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.6381 - loss: 0.1137
# Epoch 213/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6386 - loss: 0.1129
# Epoch 214/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6403 - loss: 0.1120
# Epoch 215/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6411 - loss: 0.1112
# Epoch 216/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6420 - loss: 0.1103
# Epoch 217/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6486 - loss: 0.1095
# Epoch 218/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6490 - loss: 0.1087
# Epoch 219/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6500 - loss: 0.1079
# Epoch 220/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6509 - loss: 0.1071
# Epoch 221/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6528 - loss: 0.1063
# Epoch 222/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6559 - loss: 0.1056
# Epoch 223/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6600 - loss: 0.1048
# Epoch 224/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6607 - loss: 0.1041
# Epoch 225/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.6618 - loss: 0.1034
# Epoch 226/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6654 - loss: 0.1027
# Epoch 227/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6672 - loss: 0.1019
# Epoch 228/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6679 - loss: 0.1012
# Epoch 229/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6694 - loss: 0.1006
# Epoch 230/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6709 - loss: 0.0999
# Epoch 231/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6718 - loss: 0.0992
# Epoch 232/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6731 - loss: 0.0986
# Epoch 233/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6743 - loss: 0.0979
# Epoch 234/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6756 - loss: 0.0973
# Epoch 235/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6769 - loss: 0.0967
# Epoch 236/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6782 - loss: 0.0961
# Epoch 237/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.6795 - loss: 0.0955
# Epoch 238/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6810 - loss: 0.0949
# Epoch 239/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.6853 - loss: 0.0943
# Epoch 240/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6872 - loss: 0.0937
# Epoch 241/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6883 - loss: 0.0932
# Epoch 242/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6897 - loss: 0.0926
# Epoch 243/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6917 - loss: 0.0921
# Epoch 244/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6954 - loss: 0.0915
# Epoch 245/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.6966 - loss: 0.0910
# Epoch 246/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6982 - loss: 0.0905
# Epoch 247/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.6996 - loss: 0.0900
# Epoch 248/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7006 - loss: 0.0895
# Epoch 249/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7025 - loss: 0.0890
# Epoch 250/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7047 - loss: 0.0885
# Epoch 251/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7064 - loss: 0.0880
# Epoch 252/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7099 - loss: 0.0875
# Epoch 253/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.7176 - loss: 0.0871
# Epoch 254/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7193 - loss: 0.0866
# Epoch 255/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7215 - loss: 0.0862
# Epoch 256/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7234 - loss: 0.0857
# Epoch 257/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7258 - loss: 0.0853
# Epoch 258/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7271 - loss: 0.0849
# Epoch 259/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7295 - loss: 0.0845
# Epoch 260/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7315 - loss: 0.0840
# Epoch 261/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7335 - loss: 0.0836
# Epoch 262/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7347 - loss: 0.0832
# Epoch 263/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7375 - loss: 0.0829
# Epoch 264/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7397 - loss: 0.0825
# Epoch 265/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7407 - loss: 0.0821
# Epoch 266/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.7431 - loss: 0.0817
# Epoch 267/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7444 - loss: 0.0814
# Epoch 268/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7483 - loss: 0.0810
# Epoch 269/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7548 - loss: 0.0806
# Epoch 270/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7566 - loss: 0.0803
# Epoch 271/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7589 - loss: 0.0800
# Epoch 272/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7603 - loss: 0.0796
# Epoch 273/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7647 - loss: 0.0793
# Epoch 274/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7659 - loss: 0.0790
# Epoch 275/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7682 - loss: 0.0787
# Epoch 276/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7748 - loss: 0.0783
# Epoch 277/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7757 - loss: 0.0780
# Epoch 278/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7784 - loss: 0.0777
# Epoch 279/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7789 - loss: 0.0774
# Epoch 280/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7815 - loss: 0.0772
# Epoch 281/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.7831 - loss: 0.0769
# Epoch 282/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7842 - loss: 0.0766
# Epoch 283/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7859 - loss: 0.0763
# Epoch 284/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7880 - loss: 0.0760
# Epoch 285/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7897 - loss: 0.0758
# Epoch 286/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7908 - loss: 0.0755
# Epoch 287/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7923 - loss: 0.0753
# Epoch 288/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7941 - loss: 0.0750
# Epoch 289/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.7962 - loss: 0.0748
# Epoch 290/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7969 - loss: 0.0745
# Epoch 291/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.7989 - loss: 0.0743
# Epoch 292/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8019 - loss: 0.0740
# Epoch 293/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8042 - loss: 0.0738
# Epoch 294/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8056 - loss: 0.0736
# Epoch 295/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8070 - loss: 0.0734
# Epoch 296/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8084 - loss: 0.0731
# Epoch 297/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8093 - loss: 0.0729
# Epoch 298/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8107 - loss: 0.0727
# Epoch 299/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8123 - loss: 0.0725
# Epoch 300/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8131 - loss: 0.0723
# Epoch 301/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8142 - loss: 0.0721
# Epoch 302/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8155 - loss: 0.0719
# Epoch 303/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8168 - loss: 0.0717
# Epoch 304/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8175 - loss: 0.0715
# Epoch 305/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8232 - loss: 0.0713
# Epoch 306/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8246 - loss: 0.0711
# Epoch 307/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - AUC: 0.8245 - loss: 0.0710
# Epoch 308/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8259 - loss: 0.0708
# Epoch 309/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8294 - loss: 0.0706
# Epoch 310/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8309 - loss: 0.0704
# Epoch 311/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8312 - loss: 0.0703
# Epoch 312/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8326 - loss: 0.0701
# Epoch 313/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8340 - loss: 0.0699
# Epoch 314/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8352 - loss: 0.0698
# Epoch 315/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8356 - loss: 0.0696
# Epoch 316/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8363 - loss: 0.0695
# Epoch 317/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8378 - loss: 0.0693
# Epoch 318/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8387 - loss: 0.0692
# Epoch 319/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8393 - loss: 0.0690
# Epoch 320/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8402 - loss: 0.0689
# Epoch 321/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8406 - loss: 0.0687
# Epoch 322/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8414 - loss: 0.0686
# Epoch 323/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8424 - loss: 0.0684
# Epoch 324/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8429 - loss: 0.0683
# Epoch 325/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8435 - loss: 0.0682
# Epoch 326/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8442 - loss: 0.0680
# Epoch 327/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8446 - loss: 0.0679
# Epoch 328/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8456 - loss: 0.0678
# Epoch 329/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8503 - loss: 0.0677
# Epoch 330/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8509 - loss: 0.0675
# Epoch 331/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8512 - loss: 0.0674
# Epoch 332/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8513 - loss: 0.0673
# Epoch 333/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8534 - loss: 0.0672
# Epoch 334/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8543 - loss: 0.0671
# Epoch 335/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8541 - loss: 0.0670
# Epoch 336/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8548 - loss: 0.0669
# Epoch 337/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8559 - loss: 0.0667
# Epoch 338/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8562 - loss: 0.0666
# Epoch 339/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8567 - loss: 0.0665
# Epoch 340/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8571 - loss: 0.0664
# Epoch 341/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8573 - loss: 0.0663
# Epoch 342/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8591 - loss: 0.0662
# Epoch 343/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8593 - loss: 0.0661
# Epoch 344/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8603 - loss: 0.0660
# Epoch 345/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8603 - loss: 0.0659
# Epoch 346/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8615 - loss: 0.0658
# Epoch 347/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8612 - loss: 0.0657
# Epoch 348/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - AUC: 0.8620 - loss: 0.0656
# Epoch 349/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8622 - loss: 0.0656
# Epoch 350/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8625 - loss: 0.0655
# Epoch 351/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8633 - loss: 0.0654
# Epoch 352/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8635 - loss: 0.0653
# Epoch 353/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8647 - loss: 0.0652
# Epoch 354/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8648 - loss: 0.0651
# Epoch 355/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8652 - loss: 0.0650
# Epoch 356/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8659 - loss: 0.0650
# Epoch 357/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8664 - loss: 0.0649
# Epoch 358/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8669 - loss: 0.0648
# Epoch 359/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8674 - loss: 0.0647
# Epoch 360/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8643 - loss: 0.0646
# Epoch 361/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8648 - loss: 0.0646
# Epoch 362/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8650 - loss: 0.0645
# Epoch 363/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8653 - loss: 0.0644
# Epoch 364/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8657 - loss: 0.0643
# Epoch 365/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8658 - loss: 0.0643
# Epoch 366/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8657 - loss: 0.0642
# Epoch 367/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8663 - loss: 0.0641
# Epoch 368/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8668 - loss: 0.0641
# Epoch 369/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8666 - loss: 0.0640
# Epoch 370/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8680 - loss: 0.0639
# Epoch 371/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8680 - loss: 0.0638
# Epoch 372/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8680 - loss: 0.0638
# Epoch 373/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8684 - loss: 0.0637
# Epoch 374/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8693 - loss: 0.0637
# Epoch 375/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8693 - loss: 0.0636
# Epoch 376/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8697 - loss: 0.0635
# Epoch 377/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8701 - loss: 0.0635
# Epoch 378/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8696 - loss: 0.0634
# Epoch 379/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8696 - loss: 0.0633
# Epoch 380/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8703 - loss: 0.0633
# Epoch 381/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8711 - loss: 0.0632
# Epoch 382/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8708 - loss: 0.0632
# Epoch 383/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8708 - loss: 0.0631
# Epoch 384/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8707 - loss: 0.0630
# Epoch 385/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8702 - loss: 0.0630
# Epoch 386/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8702 - loss: 0.0629
# Epoch 387/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8705 - loss: 0.0629
# Epoch 388/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8709 - loss: 0.0628
# Epoch 389/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8719 - loss: 0.0628
# Epoch 390/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8720 - loss: 0.0627
# Epoch 391/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8718 - loss: 0.0627
# Epoch 392/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8716 - loss: 0.0626
# Epoch 393/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8716 - loss: 0.0626
# Epoch 394/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8721 - loss: 0.0625
# Epoch 395/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8720 - loss: 0.0624
# Epoch 396/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8720 - loss: 0.0624
# Epoch 397/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8717 - loss: 0.0623
# Epoch 398/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8717 - loss: 0.0623
# Epoch 399/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8727 - loss: 0.0622
# Epoch 400/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8727 - loss: 0.0622
# Epoch 401/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8725 - loss: 0.0621
# Epoch 402/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8728 - loss: 0.0621
# Epoch 403/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8730 - loss: 0.0621
# Epoch 404/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8729 - loss: 0.0620
# Epoch 405/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8728 - loss: 0.0620
# Epoch 406/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8729 - loss: 0.0619
# Epoch 407/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8730 - loss: 0.0619
# Epoch 408/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8731 - loss: 0.0618
# Epoch 409/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8727 - loss: 0.0618
# Epoch 410/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8731 - loss: 0.0617
# Epoch 411/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8735 - loss: 0.0617
# Epoch 412/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8738 - loss: 0.0616
# Epoch 413/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8738 - loss: 0.0616
# Epoch 414/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8741 - loss: 0.0616
# Epoch 415/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8740 - loss: 0.0615
# Epoch 416/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8736 - loss: 0.0615
# Epoch 417/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8741 - loss: 0.0614
# Epoch 418/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8742 - loss: 0.0614
# Epoch 419/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8747 - loss: 0.0613
# Epoch 420/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8746 - loss: 0.0613
# Epoch 421/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8746 - loss: 0.0613
# Epoch 422/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8746 - loss: 0.0612
# Epoch 423/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8747 - loss: 0.0612
# Epoch 424/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0611
# Epoch 425/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0611
# Epoch 426/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8749 - loss: 0.0611
# Epoch 427/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8750 - loss: 0.0610
# Epoch 428/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0610
# Epoch 429/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8748 - loss: 0.0609
# Epoch 430/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8749 - loss: 0.0609
# Epoch 431/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8754 - loss: 0.0609
# Epoch 432/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8755 - loss: 0.0608
# Epoch 433/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8753 - loss: 0.0608
# Epoch 434/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0607
# Epoch 435/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8755 - loss: 0.0607
# Epoch 436/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8754 - loss: 0.0607
# Epoch 437/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8754 - loss: 0.0606
# Epoch 438/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0606
# Epoch 439/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8744 - loss: 0.0605
# Epoch 440/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8746 - loss: 0.0605
# Epoch 441/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8747 - loss: 0.0605
# Epoch 442/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8747 - loss: 0.0604
# Epoch 443/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0604
# Epoch 444/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8757 - loss: 0.0604
# Epoch 445/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8758 - loss: 0.0603
# Epoch 446/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8759 - loss: 0.0603
# Epoch 447/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8758 - loss: 0.0603
# Epoch 448/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8758 - loss: 0.0602
# Epoch 449/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8765 - loss: 0.0602
# Epoch 450/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8765 - loss: 0.0601
# Epoch 451/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8766 - loss: 0.0601
# Epoch 452/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8763 - loss: 0.0601
# Epoch 453/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8762 - loss: 0.0600
# Epoch 454/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8762 - loss: 0.0600
# Epoch 455/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8763 - loss: 0.0600
# Epoch 456/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8764 - loss: 0.0599
# Epoch 457/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8760 - loss: 0.0599
# Epoch 458/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8755 - loss: 0.0599
# Epoch 459/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8750 - loss: 0.0598
# Epoch 460/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8749 - loss: 0.0598
# Epoch 461/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.0598
# Epoch 462/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0597
# Epoch 463/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8751 - loss: 0.0597
# Epoch 464/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8752 - loss: 0.0597
# Epoch 465/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8753 - loss: 0.0596
# Epoch 466/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8755 - loss: 0.0596
# Epoch 467/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8755 - loss: 0.0596
# Epoch 468/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.0595
# Epoch 469/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0595
# Epoch 470/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8747 - loss: 0.0595
# Epoch 471/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8747 - loss: 0.0594
# Epoch 472/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0594
# Epoch 473/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8748 - loss: 0.0594
# Epoch 474/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8748 - loss: 0.0593
# Epoch 475/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0593
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8754 - loss: 0.0593
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8752 - loss: 0.0592
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8754 - loss: 0.0592
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8754 - loss: 0.0592
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8755 - loss: 0.0592
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8752 - loss: 0.0591
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8752 - loss: 0.0591
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8747 - loss: 0.0591
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8749 - loss: 0.0590
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.0590
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - AUC: 0.8749 - loss: 0.0590
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - AUC: 0.8747 - loss: 0.0589
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.0589
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8749 - loss: 0.0589
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8749 - loss: 0.0589
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0588
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8747 - loss: 0.0588
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8746 - loss: 0.0588
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0587
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8748 - loss: 0.0587
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8749 - loss: 0.0587
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - AUC: 0.8751 - loss: 0.0586
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8750 - loss: 0.0586
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8751 - loss: 0.0586
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - AUC: 0.8752 - loss: 0.0586

# %%
# plot history
plt.plot(history.history['AUC'], label='AUC')
plt.legend()
plt.show()

# %%
y_test_pre=model.predict(x_test)


pa=pd.DataFrame()
pa['Date']=X_test.reset_index().year.iloc[1:-1]
pa['Prediction']=[i[0] for i in y_test_pre][1:] 
pa['Actual Values']=y_test[:-1]
pa['Prediction1'] = pa['Prediction'].apply(lambda x: 1 if x >= 0.19 else 0)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
auc_neural = metrics.roc_auc_score(pa['Actual Values'], pa['Prediction1'])

# %%
fpr, tpr, _ = metrics.roc_curve(pa['Actual Values'], pa['Prediction1'])

plt.plot(fpr,tpr,label="data 1, auc="+str(auc_neural))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Out-of-Sample Predictive Performance

# %% [markdown]
# ### Recall Rates

# %% [markdown]
# ### ROC Curve

# %%
# Logistic Model 
score_logistic = cross_val_score(LogisticRegression(penalty = 'none'), X_standardized, y, cv=5, scoring='roc_auc')
# Print the mean ROC AUC score
print("Mean ROC AUC Score for Logistic:", score_logistic.mean())
# Lasso
score_lasso = cross_val_score(LogisticRegression(penalty='l1', solver = 'liblinear', C = 1/0.41), X_standardized, y, cv=5, scoring='roc_auc')
# Print the mean ROC AUC score
print("Mean ROC AUC Score for Lasso:", score_lasso.mean())

# Elastic Net
#score_EN = cross_val_score(LogisticRegression(solver =  'saga', penalty = 'elasticnet'), X_standardized, y, cv=5, scoring='roc_auc')
# Print the mean ROC AUC score
#print("Mean ROC AUC Score:", score_EN.mean())

# Random Forest

score_RF = cross_val_score(RandomForestClassifier(n_estimators=250, max_features = 4, random_state=42), X_standardized, y, cv=5, scoring='roc_auc')
print("Mean ROC AUC Score for Random Forest:", score_RF.mean())

# Gradient Boost


# Neural Network
print("ROC AUC Score for RNN:", auc_neural)
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# Mean ROC AUC Score for Logistic: 0.8014632391418106
# Mean ROC AUC Score for Lasso: 0.8340548142333857
# Mean ROC AUC Score for Random Forest: 0.7744930664573522
# ROC AUC Score for RNN: 0.9842995169082125

# %% [markdown]
# ### Shapley Values
