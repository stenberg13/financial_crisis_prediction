# %% [markdown]
# # Early Warning Models for Financial Crisis using Machine Learning Techniques

# %% [markdown]
# ### Yelebe Desta and Seth Tenberg

# %% [markdown]
# # Introduction

# %% [markdown]
# Financial Crises have caused massive economic disruption and panic over the course of the last 200 years. These Black Swan events are incredibly difficult to predict, and can cause widespread unemployment and financially ruin the lives of millions. People oftentimes use indicators like the yield curve to predict when these events will occur; while yield curve inversion is a relatively good predictor of recession, it does not offer a timeable prediction nor does it give us insight into what other factors signal crisis.

# %% [markdown]
# Machine learning techniques focused on prediction may provide a way to improve upon the forecasting of financial crisis. Machine learning techniques can capture nonlinear relationships that may play into macroeconomic dynamics, and allow researchers to incorporate larger data for prediction.

# %% [markdown]
# Previous research has been done on this subject, and it has been shown that machine learning techniques can be used as a superior method for predicting financial crisis. This analysis will replicate the results from (Bluwstein et. al. 2021) where multiple machine learning techniques are used to forecast financial crisis on a global scale. We will extend their work by combining work on long short term memory (lstm) models from (Tolo, 2019), and incorporate lstm models for the purpose of predicting financial crises.

# %% [markdown]
# The goal of this analysis is to create an early warning system that predicts when a financial crisis will occur one or two years in advance. Our main research question is as follows: Do machine learning models provide better prediction in forecasting financial crises than traditional econometric models?

# %% [markdown]
# This research is important for policy-makers and investors alike, as understanding when crises will occur can help monetary policy shift from a re-active stance to a pro-active stance. This could allow entities like the Federal Reserve to styme crisis or prevent panic crashes from ensuing. For investors, knowing when to hedge against downside potential in a portfolio is incredibly valuable and can save investors from large losses in the event of crisis.

# %% [markdown]
# # Cleaning the Data

# %% [markdown]
# The dataset used for this analysis is the Jordà-Schularick-Taylor Macrohistory Database. This is the longest running dataset that covers macrofinancial data and records when financial crises occur. The panel data spans 17 countries across the years 1870-2016. We choose this dataset to maximize the number of financial crises observed, as these events are (thankfully) rare. Variables in this dataset include, the cpi rate, housing prices, GDP, bond and bill rates, return on equity, money supply, debt/gdp ratio, and other macrofinancial variables.

# %%
# some packages may have to be installed depending on what you already have installed.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import f1_score

from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import recall_score

from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from keras.optimizers import Adam
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score

set_seed(455)
# Out:
# WARNING:tensorflow:From C:\Users\sjten\anaconda3\Lib\site-packages\keras\losses.py:2664: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 27
#      25 from sklearn.metrics import mean_squared_error
#      26 import tensorflow as tf
# ---> 27 from tensorflow.keras.models import Sequential
#      28 from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
#      29 from tensorflow.keras.optimizers import SGD
#
# File ~\anaconda3\Lib\site-packages\keras\api\_v2\keras\__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
#       5 Detailed documentation and user guides are available at
#       6 [keras.io](https://keras.io).
#       7
#       8 """
#      10 import sys as _sys
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# File ~\anaconda3\Lib\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\anaconda3\Lib\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\anaconda3\Lib\site-packages\keras\engine\functional.py:34
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.legacy import serialization
#
# File ~\anaconda3\Lib\site-packages\keras\engine\training.py:40
#      38 from keras.optimizers import optimizer_v1
#      39 from keras.saving import pickle_utils
# ---> 40 from keras.saving import saving_api
#      41 from keras.saving import saving_lib
#      42 from keras.saving import serialization_lib
#
# File ~\anaconda3\Lib\site-packages\keras\saving\saving_api.py:24
#      21 from tensorflow.python.util.tf_export import keras_export
#      23 from keras.saving import saving_lib
# ---> 24 from keras.saving.legacy import save as legacy_sm_saving_lib
#      25 from keras.utils import io_utils
#      27 try:
#
# File ~\anaconda3\Lib\site-packages\keras\saving\legacy\save.py:27
#      25 from keras.saving.legacy import serialization
#      26 from keras.saving.legacy.saved_model import load as saved_model_load
# ---> 27 from keras.saving.legacy.saved_model import load_context
#      28 from keras.saving.legacy.saved_model import save as saved_model_save
#      29 from keras.saving.legacy.saved_model.utils import keras_option_scope
#
# File ~\anaconda3\Lib\site-packages\keras\saving\legacy\saved_model\load_context.py:68
#      64     """Returns whether under a load context."""
#      65     return _load_context.in_load_context()
# ---> 68 tf.__internal__.register_load_context_function(in_load_context)
#
# AttributeError: module 'tensorflow._api.v2.compat.v2.__internal__' has no attribute 'register_load_context_function'

# %%
# the file is on github which is linked below, reading it in will be slightly different depending on where you save file, this is an excel file
# https://github.com/stenberg13/financial_crisis_prediction/blob/58f365fcbd89741ecb778597e21f8ed136e29d56/JSTdatasetR6%20(1).xlsx
data = pd.read_excel("C:/Users/sjten/Downloads/JSTdatasetR6 (1).xlsx")

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#              year          ifs            pop       rgdpmad    rgdpbarro  \
# count  2718.00000  2718.000000    2667.000000   2666.000000  2664.000000
# mean   1945.00000   148.333333   31439.397574   9155.064763    39.793748
# std      43.59701    24.165940   45898.993728   7976.190143    33.884462
# min    1870.00000   111.000000    1675.000000    737.375497     3.263085
# 25%    1907.00000   132.000000    4866.650000   2873.047663    12.694448
# 50%    1945.00000   143.000000   10113.530000   5477.011227    23.056114
# 75%    1983.00000   172.000000   45077.000000  14619.435708    65.770534
# max    2020.00000   193.000000  329239.715278  45887.569802   147.282620
#
#         rconsbarro           gdp           iy           cpi            ca  \
# count  2561.000000  2.641000e+03  2425.000000  2.666000e+03  2.489000e+03
# mean     42.133609  2.454826e+06     0.188838  4.191118e+01 -4.572271e+04
# std      32.274402  1.615548e+07     0.064621  5.689962e+01  7.670287e+05
# min       4.074400  1.250757e-11     0.017287  1.150362e-11 -1.687900e+07
# 25%      15.650000  5.428200e+01     0.140980  2.526395e+00 -6.345947e+01
# 50%      27.846700  1.810926e+03     0.194356  1.050679e+01 -3.300000e-02
# 75%      68.720000  5.038345e+04     0.230288  7.617557e+01  1.788000e+01
# max     120.431162  2.070466e+08     0.546975  2.268252e+02  5.885998e+06
#
#        ...    eq_capgain        eq_dp  eq_capgain_interp  eq_tr_interp  \
# count  ...  2.170000e+03  2169.000000                7.0           7.0
# mean   ...  1.167935e+06     0.040949                1.0           1.0
# std    ...  5.440622e+07     0.017111                0.0           0.0
# min    ... -8.842261e-01     0.000000                1.0           1.0
# 25%    ... -5.496224e-02     0.030100                1.0           1.0
# 50%    ...  4.175594e-02     0.040665                1.0           1.0
# 75%    ...  1.568719e-01     0.051569                1.0           1.0
# max    ...  2.534419e+09     0.127113                1.0           1.0
#
#        eq_dp_interp    bond_rate   eq_div_rtn   capital_tr     risky_tr  \
# count           6.0  2381.000000  2163.000000  1830.000000  1854.000000
# mean            1.0     0.054346     0.042763     0.099308     0.111523
# std             0.0     0.031442     0.017694     0.090360     0.110373
# min             1.0    -0.035316     0.000000    -0.232140    -0.238515
# 25%             1.0     0.036000     0.032112     0.047950     0.051188
# 50%             1.0     0.046100     0.042530     0.090982     0.102568
# 75%             1.0     0.063500     0.053196     0.137372     0.159925
# max             1.0     0.237154     0.138189     1.144161     1.281639
#
#            safe_tr
# count  2247.000000
# mean      0.051634
# std       0.048357
# min      -0.152371
# 25%       0.024857
# 50%       0.043005
# 75%       0.067896
# max       0.408514
#
# [8 rows x 55 columns]

# %% [markdown]
# We want to make a early warning indicator model, thus our dependent variable of interest is not when the crisis occurs, but a year or two *before* the crisis occurs. The dataset being used encodes the year that a crisis occurs; we can do a quick fix to create our binary dependent variable.

# %%
data['indicator'] = ((data['crisisJST'].shift(-1) == 1) | (data['crisisJST'].shift(-2) == 1)).astype(int)

# %% [markdown]
# Now we will remove the year of the crisis along with the following four years to remove post crisis bias, which has been shown to affect analysis in previous research.

# %%
crisis_rows = data[data['crisisJST'] == 1].index.tolist()
crisis_rows_incremented1 = [row + 1 for row in crisis_rows]
crisis_rows_incremented2 = [row + 2 for row in crisis_rows]
crisis_rows_incremented3 = [row + 3 for row in crisis_rows]
crisis_rows_incremented4 = [row + 4 for row in crisis_rows]

crisis_rows_df = pd.DataFrame(
    {'crisis_rows': crisis_rows,
     'crisis_rows_incremented1': crisis_rows_incremented1,
     'crisis_rows_incremented2': crisis_rows_incremented2,
     'crisis_rows_incremented3': crisis_rows_incremented3,
     'crisis_rows_incremented4': crisis_rows_incremented4})

rows_to_remove = pd.concat([crisis_rows_df[col] for col in crisis_rows_df.columns])

# Sort the values in the combined column
rows_to_remove = rows_to_remove.sort_values()
# remove the rows from the data to account for crisis bias
data = data.drop(data.index[rows_to_remove])
# we have removed 435 from the dataset

# %% [markdown]
# Now we wil account for extraordinary events in history, and remove the years during which World War 1, the Great Depression, and World War 2. Then we will also create two new variables for our analysis. We create a measure of global credit creation, and a measure for the global slope of the yield curve.

# %%
# we will create a variable the measures the slope of the yield curve, subtracting short term interest rates from long term interest rates
data['slope'] = (data['ltrate'] - data['stir'])
# removing years for WW1, WW2, and Great Depression
data_filtered = data[(data['year'] < 1914) | (data['year'] > 1918)]
data = data_filtered[(data_filtered['year'] < 1933) | (data_filtered['year'] > 1945)]
data['year']
# now we will create our global slope and credit variables
grouped = data.groupby('year')
data = grouped.apply(lambda x: x.assign(
    global_slope=x.loc[x['country'] != x['country'].iloc[0], 'slope'].mean()
))

# Ungroup
data= data.reset_index(drop=True)

#making Debt Servicing Ratio Variable
data['DSR'] = (data['tloans'] - (data['ltrate']/data['gdp']))

# %% [markdown]
# To ensure stationarity of the time series data, we will augment most of our variables. CPI, Real Consumption per Capita, Housing prices, Money Supply, Credit Supply, Investment, and current account are all converted into growth rates ratios of GDP. We also change Stock prices, Debt/GDP ratio, and Debt Servicing Ratio are all changed into one year rates of change.

# %%
data_rate = data.groupby('country').apply(lambda group: 
    group.assign(
        cpi_rate = (group['cpi'] - group['cpi'].shift(1)) / group['cpi'].shift(1),
        rconsumption_rate = (group['rconsbarro'] - group['rconsbarro'].shift(1)) / group['rconsbarro'].shift(1),
        housing_rate = (group['hpnom'] - group['hpnom'].shift(1)) / group['hpnom'].shift(1),
        money_rate = (group['money'] - group['money'].shift(1)) / group['money'].shift(1),
        DSR_rate = (group['DSR'] - group['DSR'].shift(1)/ group['DSR'].shift(1)),
        credit_rate = (group['tloans'] / group['gdp'] - group['tloans'].shift(1) / group['gdp'].shift(1)),
        ca_rate = (group['ca'] / group['gdp'] - group['ca'].shift(1) / group['gdp'].shift(1)),
        investment_rate = (group['iy'] - group['iy'].shift(1)),
        stock_rate =  ((group['capital_tr'] - group['capital_tr'].shift(1))/group['capital_tr'].shift(1)),
        debtgdp_rate = (group['debtgdp'] - group['debtgdp'].shift(1)),
        lev_rate = (group['lev'] - group['lev'].shift(1)),
        noncore_rate = (group['noncore'] - group['noncore'].shift(1))


    )
).reset_index(drop=True)

grouped = data_rate.groupby('year')
data_rate = grouped.apply(lambda x: x.assign(
    global_credit_rate=x.loc[x['country'] != x['country'].iloc[0], 'credit_rate'].mean()
))

# Ungroup
data_rate= data_rate.reset_index(drop=True)

# %%
columns_to_keep = ['cpi_rate', 'rconsumption_rate', 'housing_rate', 'money_rate', 'DSR_rate', 'credit_rate', 
                   'global_credit_rate', 'slope', 'global_slope','ca_rate',  'investment_rate',  'debtgdp_rate', 'noncore_rate', 'lev_rate', 'stock_rate', 'indicator']
data_subset = data_rate[columns_to_keep]

missing_rows = data_subset[data_subset.isnull().any(axis=1)]

# Print the number of rows with missing values
print("Number of rows with missing values:", len(missing_rows))
# Out:
# Number of rows with missing values: 951

# %%
columns_to_keep1 = ['year', 'country', 'cpi_rate', 'rconsumption_rate', 'housing_rate', 'money_rate', 'DSR_rate', 'credit_rate', 
                   'global_credit_rate', 'slope', 'global_slope','ca_rate',  'investment_rate',  'debtgdp_rate', 'noncore_rate', 'lev_rate', 'stock_rate', 'indicator']
data_subset1 = data_rate[columns_to_keep1]

# %%
# dropping all the rows with na's 
data_subset = data_subset.dropna()
data_subset1 = data_subset1.dropna()

# %%
# standardizing the data
X = data_subset.drop(columns=['indicator'])
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler to the data and transform the data
X_standardized = scaler.fit_transform(X)

# Convert the standardized array back to a DataFrame with column names
X_standardized = pd.DataFrame(X_standardized, columns=X.columns)
X_standardized.head()
y = data_subset['indicator']

# %%
columns_to_standardize = [col for col in X1.columns if col not in ['year', 'country']]

# Standardize selected columns
scaler = StandardScaler()
X_standardized1 = X1.copy()  # Create a copy of the original DataFrame
X_standardized1[columns_to_standardize] = scaler.fit_transform(X_standardized1[columns_to_standardize])

# %%
X_standardized1 = X_standardized1.rename(columns={'year' : 'Year','country' : 'Country','cpi_rate' : 'CPI Rate', 'rconsumption_rate' : 'Consumption Rate', 'housing_rate' : 'Housing Rate', 'money_rate' : 'Money Rate', 'DSR_rate' : 'DSR Rate',
                      'credit_rate' : 'Credit Rate', 'ca_rate' : 'CA Rate', 'investment_rate' : 'Investment Rate', 'stock_rate' : 'Stock Rate', 'debtgdp_rate' : 'Debt/GDP Rate',
                      'slope' : 'Slope', 'global_slope': 'Global Slope', 'global_credit_rate' : 'Global Credit Rate','lev_rate' : 'Leverage', 'noncore_rate' : 'Noncore'})

# %%
X_standardized = X_standardized.rename(columns={'cpi_rate' : 'CPI Rate', 'rconsumption_rate' : 'Consumption Rate', 'housing_rate' : 'Housing Rate', 'money_rate' : 'Money Rate', 'DSR_rate' : 'DSR Rate',
                      'credit_rate' : 'Credit Rate', 'ca_rate' : 'CA Rate', 'investment_rate' : 'Investment Rate', 'stock_rate' : 'Stock Rate', 'debtgdp_rate' : 'Debt/GDP Rate',
                      'slope' : 'Slope', 'global_slope': 'Global Slope', 'global_credit_rate' : 'Global Credit Rate','lev_rate' : 'Leverage', 'noncore_rate' : 'Noncore'})
X_standardized.head()
# Out:
#    CPI Rate  Consumption Rate  Housing Rate  Money Rate  DSR Rate  \
# 0 -0.692399          1.863803     -1.275025    0.232034 -9.774171
# 1 -0.627131         -1.129922     -0.489277   -0.331442 -9.580488
# 2 -0.017208         -1.905575     -0.962707   -0.392559 -9.114716
# 3 -0.549623         -0.076285      0.484746   -0.074498 -8.731604
# 4 -0.327021         -0.849147     -0.717554   -0.378533 -8.480827
#
#    Credit Rate  Global Credit Rate     Slope  Global Slope   CA Rate  \
# 0     0.372076            1.004389 -0.597122      1.450977  0.455652
# 1     0.047627            0.004045 -0.070608      0.644872 -0.214573
# 2     0.105955           -0.270948 -0.073565      0.330450 -0.123752
# 3     0.135452           -0.037695 -0.562146     -0.954545  0.135967
# 4    -0.076233            0.601057 -0.428367     -1.046299  0.198573
#
#    Investment Rate  Debt/GDP Rate   Noncore  Leverage  Stock Rate
# 0        -3.187647       0.642133  1.805039 -9.998045   -0.200192
# 1        -1.711090       0.642133 -0.042318 -0.669793    0.056269
# 2         0.357629       0.354910 -0.167026  0.015099   -0.055297
# 3         0.761965       0.067688  0.031964  0.231328    0.002696
# 4        -0.250115       0.211299 -0.216842 -0.118058   -0.059341

# %% [markdown]
# Now the data is standardized and the variable names are clear for future use later.

# %%
# Calculate correlation matrix
correlation_matrix = X_standardized.corr()

# Create Seaborn heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Plot (Selected Variables)')
plt.show()

# %% [markdown]
# While most variables are uncorrelated with one another, a few variables do have moderately strong relationships with our other explanatory variables. The CPI rate and the money supply growth rate have a very strong correlation (0.79). Noticably, the global and domestic slope variables have a correlation around 0.5. Our global and domestic variables appear to measure different things and are not highly correlated alternatives.

# %% [markdown]
# The next two charts are before the data is processed, just to get a sense of how certain variables have looked over time

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='year', y='ltrate', hue='country')
plt.title('Long Term Bond Rates by Country')
plt.xlabel('Year')
plt.ylabel('Long Term Bond Rate')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='year', y='hpnom', hue='country')
plt.title('Housing Prices by Country')
plt.xlabel('Year')
plt.ylabel('Housing Price')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The following three charts are the variables that are unstandardized but have been converted into rates

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=X_standardized1, x='Year', y='Credit Rate', hue='Country')
plt.title('Credit Growth Rate by country')
plt.xlabel('Year')
plt.ylabel('Rate')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=X_standardized1, x='Year', y='Slope', hue='Country')
plt.title('Slope of the Yield Curve by country')
plt.xlabel('Year')
plt.ylabel('Slope')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=X_standardized1, x='Year', y='Debt/GDP Rate', hue='Country')
plt.title('Debt-to-GDP Ratio Rate by country')
plt.xlabel('Year')
plt.ylabel('Rate')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=X_standardized1, x='Year', y='Leverage', hue='Country')
plt.title('Capital Ratio Rate (Leverage Rate) by country')
plt.xlabel('Year')
plt.ylabel('Rate')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\sjten\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Overall, we see there are some drastic outliers, especially in the earler sections of the data surrounding the World Wars. However, the data has been transformed and standardized and is ready for modeling.

# %% [markdown]
# # Modeling

# %% [markdown]
# To begin the analysis, we will construct a logistic model with all the variables included. This will serve as a baseline to reference for model performance. For analyze out-of-sample predictive performance, we will split the data into a training and testing set, we will use k-fold cross validation to tune hyperparameters as necessary. Given the limited number of financial crises, splitting the data into a training and testing set may reduce predictive capabilities of the models, but previous research has shown that the two methods will perform comparably. We will use multiple methods to compare model performance. These methods include examining the Receiver Operating Characteristic space, F1-Score, and Shapley Values. These methods will be discussed later on.

# %% [markdown]
# We will use multiple machine learning models to predict financial crisis. To account for the moderate size of predictors we have, we use Lasso and Elastic Net models to penalize the number of parameters. We also incorporate other machine learning algorithms like random forest and gradient boosting to see if these models improve performance by capturing nonlinear relationships in the data.

# %% [markdown]
# Finally, we use a LSTM reccurrent neural network to try to capture the nonlinear dynamics in the data and assess how these various machine learning techniques performed in forecasting financial crisis.

# %% [markdown]
# We are interested in both model interpretability and predictive capability; by utilizing machine learning techniques we are able to gain new insights into the dynamics of financial crises by the inclusion of the various features afforded to us by the large dataset being used.

# %% [markdown]
# ## Basic Logistic Model
#
# To begin the analysis, we will construct a logistic model with all the variables included. This will serve as a baseline to reference for model performance. For analyze out-of-sample predictive performance, we will use a k-fold-crossfold validation method. Given the limited number of financial crises, splitting the data into a training and testing set would reduce predictive capabilities of the models. Previous research has shown that the two methods will perform comparably. We will use multiple methods to compare model performance. These methods include examining the *Receiver Operating Characteristic* space, Recall rate, and Shapley Values. These methods will be discussed later on.

# %% [markdown]
# We will now create the models that will be used for predicting financial crises. We will investigate the variables of importance and see if there are any variables that are consistantly important across all the models. Then the models will be tested for predictive performance.

# %%
X_standardized['intercept']=1.0
#y #1057
#X_standardized #1057
y = list(y)
logit = sm.Logit(y, X_standardized)
logit_fit=logit.fit()


logit_fit.summary()
coeff = logit_fit.params
# Out:
# Optimization terminated successfully.
#          Current function value: 0.207378
#          Iterations 9

# %%
coefficients = logit_fit.params
coefficients = coefficients.drop(['intercept'])
coef_names = coefficients.index

sorted_coefficients = sorted(zip(coefficients, coef_names), reverse=True)
sorted_coefficients, sorted_coef_names = zip(*sorted_coefficients)

cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
plt.barh(sorted_coef_names, sorted_coefficients, color=cmap(abs(coefficients) / max(abs(coefficients))))

plt.xlabel('Variable')
plt.ylabel('Coefficient')
plt.title('Coefficients Plot for Logistic Model')
plt.xticks(rotation=90)
plt.show()

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

# %% [markdown]
# This chart illustrates the most important feautures in our logistic model. As seen above, the most important features are The global and domestic credit growth rates, the global and domestic yield curve slopes, noncore funding, and Debt/GDP ratio.

# %% [markdown]
# # Lasso Model

# %% [markdown]
# We will now implement penalized logistic models. First we create a Lasso logistic model and tune the model using cross-validation to find a good value for the penalty term. Then the coefficients are plotted from the model using the *good* penalty term.

# %%
from sklearn.model_selection import cross_val_score

alpha_values = [0.0001, 0.001,0.005, 0.01, 0.1, 0.5, 1]
best_alpha = None
best_mse = float('inf')

cv_scores = {}

# Perform manual grid search with cross-validation
for alpha in alpha_values:
    lasso = Lasso(alpha=alpha)
    scores = cross_val_score(lasso, X_standardized, y, cv=5, scoring='neg_mean_squared_error')
    cv_scores[alpha] = np.mean(scores)

# Find the alpha with the best mean cross-validation score
best_alpha = min(cv_scores, key=cv_scores.get)
best_mse = -cv_scores[best_alpha]

print("Best Alpha:", best_alpha)
print("Best Cross-Validation MSE:", best_mse)
# Out:
# Best Alpha: 0.0001
# Best Cross-Validation MSE: 0.07215348889817944

# %%
from sklearn.linear_model import LinearRegression, Lasso
# model evaluation
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV


lasso_best = Lasso(alpha=best_alpha)
lasso_best.fit(X_standardized, y)


coeff_lasso = lasso_best.coef_
columns = ['Lasso_Coefficient', 'Feature']
new_df = pd.DataFrame(X_standardized.columns,coeff_lasso)





data = {'coeff_lasso': coeff_lasso, 'column_names': X_standardized.columns}

# Create DataFrame
df = pd.DataFrame(data)

df = df.drop(df.index[-1])

df = df.sort_values(by = 'coeff_lasso', ascending = False)

# %%
column_names = df['column_names']
coeff_lasso = df['coeff_lasso']

# Define colormap 'viridis'
cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
bars = plt.barh(column_names, coeff_lasso, color=cmap(abs(coeff_lasso) / max(abs(coeff_lasso))))
plt.xlabel('Variable')
plt.ylabel('Coefficients')
plt.title('Coefficients Plot for Lasso Model')

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([0.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

plt.show()

# %% [markdown]
# Positive values of the money supply growth rate, the global credit growth rate, and the noncore funding rate are all important for predicting financial crisis for the Lasso model. Likewise, negative values for the global slope of the yield curve, the cpi rate, and the consumption rate (GDP) are important for predicting financial crisis.

# %% [markdown]
# # Elastic Net Model

# %% [markdown]
# The Elastic Net model combines the techniques of Lasso and Ridge models. We follow the same procedure from above, and also tune the hyperparameter l1 ratio, which controls how similiar the model is to Ridge versus Lasso. The coefficients from the model are then plotted

# %%
l1_ratio_values = [0.1, 0.3, 0.5, 0.7, 0.9]
alpha_values = [  0.0001, 0.001,0.005, 0.01, 0.1, 0.5, 1]

cv_scores = {}

# Perform manual grid search with cross-validation
for alpha in alpha_values:
    for l1_ratio in l1_ratio_values:
        elastic_net = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
        scores = cross_val_score(elastic_net, X_standardized, y, cv=5, scoring='neg_mean_squared_error')
        cv_scores[(alpha, l1_ratio)] = np.mean(scores)

# Find the alpha and l1_ratio with the best mean cross-validation score
best_hyperparams = min(cv_scores, key=cv_scores.get)
best_alpha1, best_l1_ratio = best_hyperparams
best_mse = -cv_scores[best_hyperparams]

print("Best Alpha:", best_alpha1)
print("Best l1_ratio:", best_l1_ratio)
print("Best Cross-Validation MSE:", best_mse)
# Out:
# Best Alpha: 0.0001
# Best l1_ratio: 0.1
# Best Cross-Validation MSE: 0.08070185705872505

# %%
elastic_net = ElasticNet()


elastic_net_best = ElasticNet(alpha = best_alpha, l1_ratio = best_l1_ratio)
elastic_net_best.fit(X_standardized, y)


coeff_elastic_net = elastic_net_best.coef_
columns = ['Elastic_Net_Coefficient', 'Feature']
new_df = pd.DataFrame(X_standardized.columns,coeff_elastic_net)


data = {'coeff_elastic_net': coeff_elastic_net, 'column_names': X_standardized.columns}

# Create DataFrame
df = pd.DataFrame(data)

df = df.drop(df.index[-1])

df = df.sort_values(by = 'coeff_elastic_net', ascending = False)

# %%
column_names = df['column_names']
coeff_elastic_net = df['coeff_elastic_net']

# Define colormap 'viridis'
cmap = plt.cm.viridis

plt.figure(figsize=(10, 6))
bars = plt.barh(column_names, coeff_elastic_net, color=cmap(abs(coeff_elastic_net) / max(abs(coeff_elastic_net))))
plt.xlabel('Variable')
plt.ylabel('Coefficients')
plt.title('Coefficients Plot for Elastic Net Model')

# Create a separate axis for the color bar at the bottom
cbar_ax = plt.axes([0.1, 0.01, 0.8, 0.02])  # Adjust the position and size of the color bar axis
cbar = plt.colorbar(plt.cm.ScalarMappable(cmap=cmap), cax=cbar_ax, orientation='horizontal')
cbar.set_label('Strength of Coefficient in Absolute Value')

plt.show()

# %% [markdown]
# Once again we see negative values of global and domestic slope along with consumption and cpi are important for predicting crisis. Similarly, positive values of global an domestic credit growth, along with the money supply growth rate and noncore funding are important for the Elastic Net model

# %% [markdown]
# # Random Forest

# %% [markdown]
# Next we will fit a Random Forest model to the data. We will tune some of the hyperparameters to achieve a good fit, and view the variables by importance.

# %%
forest = RandomForestRegressor()


param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_features': [3, 4, 5]
}
grid_search = GridSearchCV(estimator = forest, param_grid=param_grid, cv=5)
grid_search.fit(X_standardized, y)

best_n_estimators = grid_search.best_params_['n_estimators']
best_max_features = grid_search.best_params_['max_features']

forest_best = RandomForestClassifier(n_estimators = best_n_estimators, max_features = best_max_features)
forest_best.fit(X_standardized, y)
# Out:
# RandomForestClassifier(max_features=3, n_estimators=250)

# %%
Importance = pd.DataFrame({'Importance':forest_best.feature_importances_*100}, index=X_standardized.columns)
Importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r', figsize = (10,6))
plt.xlabel('Variable Importance')
plt.title('Feature Importance Plot for Random Forest Model')
plt.gca().legend_ = None

# %% [markdown]
# The most important features for the Random Forest model include the global and domestic variables of yield curve slope and credit growth. The CPI and consumption rate are also important.

# %% [markdown]
# # Gradient Boosted Forests

# %% [markdown]
# We will now add Gradient Boosting to the Random Forest model. Once again we will tune some of the hyperparameters and analyze the variables by importance.

# %%
# may take a while to run

gbm = GradientBoostingClassifier()

param_grid = {
    'n_estimators': [100, 150, 200, 250],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01, 0.05, 0.1, 0.2]
}

grid_search = GridSearchCV(estimator=gbm, param_grid=param_grid, cv=5)
grid_search.fit(X_standardized, y)

best_n_estimators = grid_search.best_params_['n_estimators']
best_max_depth = grid_search.best_params_['max_depth']
best_learning_rate = grid_search.best_params_['learning_rate']

gbm_best = GradientBoostingClassifier(n_estimators=best_n_estimators, max_depth=best_max_depth, learning_rate=best_learning_rate)
gbm_best.fit(X_standardized, y)

importance = pd.DataFrame({'Importance': gbm_best.feature_importances_ * 100}, index=X_standardized.columns)
importance.sort_values('Importance', axis=0, ascending=True).plot(kind='barh', color='r', figsize=(10, 6))
plt.xlabel('Variable Importance')
plt.title('Feature Importance Plot for Gradient Boosting Model')
plt.gca().legend_ = None
plt.show()

# %% [markdown]
# The most important variables are the global and domestic slope and credit growth variables, along with the stock rate and cpi rate.

# %% [markdown]
# # Neural Networks

# %% [markdown]
# We will now fit and tune a neural network to the data. Previous research has shown that Long Short Term Memory models are able particularly effective for time series data. Thus we will use an LSTM model to predict financial crisis. We believe that macroeconomic dynamics that cause or predict crisis may be nonlinear and time dependent, as this is what previous research has suggested. Thus, we believe that the LSTM Model should provide a good forecast for financial crisis.

# %%
sorted_data_rate = data_rate.sort_values(by=['country', 'year'])
columns_to_keep = ['country', 'year' , 'credit_rate', 'lev_rate' ,'housing_rate', 'global_slope', 'slope', 'rconsumption_rate', 'stock_rate', 'global_credit_rate', 'indicator']
data_neural = sorted_data_rate[columns_to_keep]

missing_rows = data_neural[data_neural.isnull().any(axis=1)]

# dropping all the rows with na's 
data_neural = data_neural.dropna()

# standardizing the data
columns_to_standardize =  ['credit_rate',  'housing_rate', 'global_slope', 'slope', 'stock_rate','rconsumption_rate', 'lev_rate', 'global_credit_rate']
scaler = StandardScaler()
data_neural[columns_to_standardize] = scaler.fit_transform(data_neural[columns_to_standardize])

# %%
train_data=data_neural.iloc[:int(len(data_neural)*0.7)] 
test_data=data_neural.iloc[int(len(data_neural)*0.7):]

# %% [markdown]
# Getting the panel data ready for the LSTM model proved challenging, but the steps are outlined below. The data is first split into a 70/30 training testing set.

# %%
def train_test_split(data):
    size=int(len(data)*0.7)
    # for train data will be collected from each country's data which index is from 0-size (70%)
    x_train =data.drop(columns=['indicator']).iloc[0:size] 
    # for test data will be collected from each country's  data which index is from size to the end (30%)
    x_test = data.drop(columns=['indicator']).iloc[size:]
    y_train=data['indicator'].iloc[0:size] 
    y_test=data['indicator'].iloc[size:] 
    return x_train, x_test,y_train,y_test
# unique countries
country=list(set(data_neural.country))
# loop each country_Region and split the data into train and test data
X_train=[]
X_test=[]
Y_train=[]
Y_test=[]
for i in range(0,len(country)):
    df = data_neural[data_neural['country'] == country[i]]
    # applied the function I created above
    x_train, x_test,y_train,y_test=train_test_split(df)
    X_train.append(x_train)
    X_test.append(x_test)
    Y_train.append(y_train)
    Y_test.append(y_test)
# concatenate each train data n X_train list and Y_train list respectively
X_train=pd.concat(X_train)
Y_train=pd.DataFrame(pd.concat(Y_train))
# concatenate each test dataset in X_test list and Y_test list respectively
X_test=pd.concat(X_test)
Y_test=pd.DataFrame(pd.concat(Y_test))

# %% [markdown]
# The data is then converted into a form which can be read by the LSTM model, a one year lag is also introduced.

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def reshape_data(train,test):
    #Frame as supervised learning and drop all time t columns except
    reframed_train = series_to_supervised(train, 1, 1)
    reframed_test = series_to_supervised(test, 1, 1)
    # split into train and test sets
    train= reframed_train.values
    test=reframed_test.values
    # split into input and outputs
    train_X, y_train = train[:, :-1], train[:, -1]
    test_X, y_test = test[:, :-1], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    x_train = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    x_test = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    return x_train,x_test,y_train,y_test

# %% [markdown]
# The X and Y variables are then split, and the year and country are removed from the X variables. The data is presented as country-year pairs.

# %%
encoder = LabelEncoder()
#combine X train and Y train as train data 
train_data=pd.DataFrame()
train_data[X_train.columns]=X_train
train_data[Y_train.columns]=Y_train
train_data['country']= encoder.fit_transform(train_data['country'])
#combine X test and Y test as test data 
test_data=pd.DataFrame()
test_data[X_test.columns]=X_test
test_data[Y_test.columns]=Y_test
test_data['country']= encoder.fit_transform(test_data['country'])
# using the function to obtian reshaped data 
x_train,x_test,y_train,y_test=reshape_data(train_data,test_data)

x_train_augment = np.delete(x_train, [0, 1, 10, 11,12], axis=2)

x_test_augment =  np.delete(x_test, [0, 1, 10, 11,12], axis=2)

# %% [markdown]
# The LSTM model is now fit here. The activation function for the input layer is ReLu, and there are ten nodes in this hidden layer. There is only one hidden layer to keep this complexity of the model fromm growing too quickly. Additionally, we impliment L2 penalty terms both the input weights and the reccurent weights to prevent overfitting. We train the model with a batch size of 200 and 200 epochs. Various different hyperparameters were tested, but this layout provided a good fit for the data.

# %%
from keras import regularizers
tf.random.set_seed(6)

# design network 
# because of randomness of neural network, replication of results may require re-runs to see a 'good' result for in-sample AUC fit
model = Sequential()

# Add LSTM layer with L2 regularization
model.add(LSTM(10, activation='relu', input_shape=(x_train_augment.shape[1], x_train_augment.shape[2]),kernel_regularizer=regularizers.l2(0.05),  # Add L2 regularization with regularization strength 0.01
               recurrent_regularizer=regularizers.l2(0.05)))

model.add(Dense(units = 1,activation='relu'))
model.compile(loss='mse', optimizer='adam', metrics=['auc'])
history = model.fit(x_train_augment, y_train, epochs=200, batch_size=200, verbose=1, shuffle=False)
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - auc: 0.4483 - loss: 1.7133
# Epoch 2/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.4579 - loss: 1.6341
# Epoch 3/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.4676 - loss: 1.5584
# Epoch 4/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.4734 - loss: 1.4861
# Epoch 5/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc: 0.4829 - loss: 1.4170
# Epoch 6/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.4936 - loss: 1.3512
# Epoch 7/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5074 - loss: 1.2885
# Epoch 8/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.5162 - loss: 1.2288
# Epoch 9/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.5263 - loss: 1.1720
# Epoch 10/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5357 - loss: 1.1180
# Epoch 11/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5461 - loss: 1.0666
# Epoch 12/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5511 - loss: 1.0178
# Epoch 13/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5584 - loss: 0.9713
# Epoch 14/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5645 - loss: 0.9270
# Epoch 15/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5656 - loss: 0.8849
# Epoch 16/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5698 - loss: 0.8448
# Epoch 17/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5734 - loss: 0.8066
# Epoch 18/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5760 - loss: 0.7702
# Epoch 19/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5775 - loss: 0.7356
# Epoch 20/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.5814 - loss: 0.7026
# Epoch 21/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5839 - loss: 0.6711
# Epoch 22/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5940 - loss: 0.6412
# Epoch 23/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6023 - loss: 0.6126
# Epoch 24/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6132 - loss: 0.5853
# Epoch 25/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6297 - loss: 0.5592
# Epoch 26/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6312 - loss: 0.5344
# Epoch 27/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6412 - loss: 0.5107
# Epoch 28/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6443 - loss: 0.4882
# Epoch 29/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6527 - loss: 0.4667
# Epoch 30/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6616 - loss: 0.4462
# Epoch 31/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6744 - loss: 0.4267
# Epoch 32/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.6813 - loss: 0.4081
# Epoch 33/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6890 - loss: 0.3904
# Epoch 34/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6895 - loss: 0.3737
# Epoch 35/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6906 - loss: 0.3577
# Epoch 36/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.6939 - loss: 0.3425
# Epoch 37/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7003 - loss: 0.3281
# Epoch 38/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7045 - loss: 0.3144
# Epoch 39/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7051 - loss: 0.3014
# Epoch 40/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7088 - loss: 0.2890
# Epoch 41/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7126 - loss: 0.2772
# Epoch 42/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7173 - loss: 0.2661
# Epoch 43/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7174 - loss: 0.2555
# Epoch 44/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7204 - loss: 0.2454
# Epoch 45/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7230 - loss: 0.2358
# Epoch 46/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7261 - loss: 0.2267
# Epoch 47/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7284 - loss: 0.2181
# Epoch 48/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7300 - loss: 0.2099
# Epoch 49/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7320 - loss: 0.2021
# Epoch 50/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7355 - loss: 0.1948
# Epoch 51/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7390 - loss: 0.1878
# Epoch 52/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7386 - loss: 0.1811
# Epoch 53/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7419 - loss: 0.1748
# Epoch 54/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7445 - loss: 0.1688
# Epoch 55/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7469 - loss: 0.1631
# Epoch 56/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7491 - loss: 0.1577
# Epoch 57/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7504 - loss: 0.1526
# Epoch 58/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7542 - loss: 0.1478
# Epoch 59/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7554 - loss: 0.1432
# Epoch 60/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7574 - loss: 0.1388
# Epoch 61/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7615 - loss: 0.1347
# Epoch 62/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7629 - loss: 0.1308
# Epoch 63/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7636 - loss: 0.1271
# Epoch 64/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7648 - loss: 0.1237
# Epoch 65/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7671 - loss: 0.1204
# Epoch 66/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7684 - loss: 0.1173
# Epoch 67/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7691 - loss: 0.1143
# Epoch 68/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7720 - loss: 0.1116
# Epoch 69/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7725 - loss: 0.1089
# Epoch 70/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7748 - loss: 0.1065
# Epoch 71/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7776 - loss: 0.1041
# Epoch 72/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7774 - loss: 0.1019
# Epoch 73/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7780 - loss: 0.0998
# Epoch 74/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7767 - loss: 0.0978
# Epoch 75/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7773 - loss: 0.0960
# Epoch 76/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7786 - loss: 0.0942
# Epoch 77/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7794 - loss: 0.0926
# Epoch 78/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7791 - loss: 0.0910
# Epoch 79/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7805 - loss: 0.0896
# Epoch 80/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7808 - loss: 0.0882
# Epoch 81/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7835 - loss: 0.0869
# Epoch 82/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7827 - loss: 0.0856
# Epoch 83/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7836 - loss: 0.0845
# Epoch 84/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7842 - loss: 0.0834
# Epoch 85/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7847 - loss: 0.0823
# Epoch 86/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7845 - loss: 0.0814
# Epoch 87/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7840 - loss: 0.0804
# Epoch 88/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7843 - loss: 0.0796
# Epoch 89/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7841 - loss: 0.0787
# Epoch 90/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7845 - loss: 0.0780
# Epoch 91/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7842 - loss: 0.0772
# Epoch 92/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7860 - loss: 0.0766
# Epoch 93/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc: 0.7864 - loss: 0.0759
# Epoch 94/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7866 - loss: 0.0753
# Epoch 95/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7855 - loss: 0.0747
# Epoch 96/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7847 - loss: 0.0742
# Epoch 97/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7857 - loss: 0.0736
# Epoch 98/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7859 - loss: 0.0731
# Epoch 99/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7868 - loss: 0.0727
# Epoch 100/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7895 - loss: 0.0722
# Epoch 101/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7893 - loss: 0.0718
# Epoch 102/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7893 - loss: 0.0714
# Epoch 103/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7899 - loss: 0.0710
# Epoch 104/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7891 - loss: 0.0707
# Epoch 105/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7890 - loss: 0.0704
# Epoch 106/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7883 - loss: 0.0700
# Epoch 107/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7884 - loss: 0.0697
# Epoch 108/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7887 - loss: 0.0695
# Epoch 109/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7894 - loss: 0.0692
# Epoch 110/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7890 - loss: 0.0690
# Epoch 111/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7897 - loss: 0.0687
# Epoch 112/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7895 - loss: 0.0685
# Epoch 113/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7892 - loss: 0.0683
# Epoch 114/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7899 - loss: 0.0681
# Epoch 115/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7896 - loss: 0.0678
# Epoch 116/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7896 - loss: 0.0676
# Epoch 117/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7905 - loss: 0.0675
# Epoch 118/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7901 - loss: 0.0673
# Epoch 119/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7911 - loss: 0.0671
# Epoch 120/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7913 - loss: 0.0670
# Epoch 121/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7909 - loss: 0.0668
# Epoch 122/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7911 - loss: 0.0667
# Epoch 123/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7906 - loss: 0.0665
# Epoch 124/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7908 - loss: 0.0664
# Epoch 125/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.7908 - loss: 0.0663
# Epoch 126/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7911 - loss: 0.0662
# Epoch 127/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7904 - loss: 0.0661
# Epoch 128/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7910 - loss: 0.0660
# Epoch 129/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7912 - loss: 0.0659
# Epoch 130/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7919 - loss: 0.0658
# Epoch 131/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7918 - loss: 0.0657
# Epoch 132/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7930 - loss: 0.0656
# Epoch 133/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7935 - loss: 0.0655
# Epoch 134/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7942 - loss: 0.0654
# Epoch 135/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7940 - loss: 0.0653
# Epoch 136/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7939 - loss: 0.0653
# Epoch 137/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7940 - loss: 0.0652
# Epoch 138/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7944 - loss: 0.0651
# Epoch 139/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7936 - loss: 0.0651
# Epoch 140/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7938 - loss: 0.0650
# Epoch 141/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7943 - loss: 0.0649
# Epoch 142/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7949 - loss: 0.0649
# Epoch 143/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7960 - loss: 0.0648
# Epoch 144/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7960 - loss: 0.0648
# Epoch 145/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7959 - loss: 0.0647
# Epoch 146/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7965 - loss: 0.0647
# Epoch 147/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7963 - loss: 0.0647
# Epoch 148/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7957 - loss: 0.0646
# Epoch 149/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7952 - loss: 0.0646
# Epoch 150/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7953 - loss: 0.0645
# Epoch 151/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7955 - loss: 0.0645
# Epoch 152/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7958 - loss: 0.0645
# Epoch 153/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7959 - loss: 0.0644
# Epoch 154/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7962 - loss: 0.0644
# Epoch 155/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7957 - loss: 0.0644
# Epoch 156/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7957 - loss: 0.0643
# Epoch 157/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7960 - loss: 0.0643
# Epoch 158/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7962 - loss: 0.0643
# Epoch 159/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7964 - loss: 0.0642
# Epoch 160/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7968 - loss: 0.0642
# Epoch 161/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7969 - loss: 0.0642
# Epoch 162/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7975 - loss: 0.0642
# Epoch 163/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7976 - loss: 0.0641
# Epoch 164/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7974 - loss: 0.0641
# Epoch 165/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7968 - loss: 0.0641
# Epoch 166/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7965 - loss: 0.0640
# Epoch 167/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7965 - loss: 0.0640
# Epoch 168/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7964 - loss: 0.0640
# Epoch 169/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7970 - loss: 0.0640
# Epoch 170/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7967 - loss: 0.0640
# Epoch 171/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7965 - loss: 0.0639
# Epoch 172/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7969 - loss: 0.0639
# Epoch 173/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7964 - loss: 0.0639
# Epoch 174/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7965 - loss: 0.0639
# Epoch 175/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7964 - loss: 0.0639
# Epoch 176/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7966 - loss: 0.0638
# Epoch 177/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7963 - loss: 0.0638
# Epoch 178/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7971 - loss: 0.0638
# Epoch 179/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7970 - loss: 0.0638
# Epoch 180/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7978 - loss: 0.0638
# Epoch 181/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7975 - loss: 0.0637
# Epoch 182/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7978 - loss: 0.0637
# Epoch 183/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7978 - loss: 0.0637
# Epoch 184/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7978 - loss: 0.0637
# Epoch 185/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7974 - loss: 0.0637
# Epoch 186/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7974 - loss: 0.0636
# Epoch 187/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7975 - loss: 0.0636
# Epoch 188/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7966 - loss: 0.0636
# Epoch 189/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7971 - loss: 0.0636
# Epoch 190/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7971 - loss: 0.0636
# Epoch 191/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.7980 - loss: 0.0635
# Epoch 192/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7981 - loss: 0.0635
# Epoch 193/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7981 - loss: 0.0635
# Epoch 194/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7984 - loss: 0.0635
# Epoch 195/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7969 - loss: 0.0635
# Epoch 196/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7960 - loss: 0.0635
# Epoch 197/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.7968 - loss: 0.0634
# Epoch 198/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.7969 - loss: 0.0634
# Epoch 199/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7977 - loss: 0.0634
# Epoch 200/200
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.7971 - loss: 0.0634

# %%
# plot history
plt.plot(history.history['auc'], label='AUC')
plt.legend()
plt.show()

# %%
y_test_pre=model.predict(x_test_augment)

pa=pd.DataFrame()
pa['Prediction']=[i[0] for i in y_test_pre][1:] 
pa['Actual Values']=y_test[:-1]
pa['Prediction1'] = pa['Prediction'].apply(lambda x: 1 if x >= 0.15 else 0)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
fpr_lstm, tpr_lstm, _ = roc_curve(pa['Actual Values'], pa['Prediction'])
roc_auc_lstm = auc(fpr_lstm, tpr_lstm)

auc_scores = [roc_auc_score(pa['Actual Values'], pa['Prediction'])]
roc_curves = [(fpr_lstm, tpr_lstm)]

# %%
auc_neural = metrics.roc_auc_score(pa['Actual Values'], pa['Prediction'])

# %%
fpr, tpr, _ = metrics.roc_curve(pa['Actual Values'], pa['Prediction'])

plt.plot(fpr,tpr,label="data 1, auc="+str(auc_neural))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# While each run will result in different results. The typical result will provide an AUC of 0.84. An explanation for this result is explained in the following section

# %% [markdown]
# # Out-of-Sample Predictive Performance

# %% [markdown]
# ## ROC Curves for Forecasting

# %% [markdown]
# To measure the out-of-sample predictive capability of our different models, we investigate the Reciever Operating Characteristic space. In this space we compare the tradeoffs between the true positive rate (the hit rate) and the false positive rate (the false alarm rate). We use AUC as a single measure of the tradeoffs, which simply measures the area under the curve in this space.

# %% [markdown]
# The following code splits the data into training and test sets, then the models are re-run and the out-of-sample predictive performance is recorded via AUC.

# %%
X_train = X_train.drop(columns=['country', 'year'])
X_test = X_test.drop(columns=['country', 'year'])

# %%
sorted_data_rate = data_rate.sort_values(by=['country', 'year'])
columns_to_keep = ['cpi_rate', 'rconsumption_rate', 'housing_rate', 'money_rate', 'DSR_rate', 'credit_rate', 'country', 'year',
                   'global_credit_rate', 'slope', 'global_slope','ca_rate',  'investment_rate',  'debtgdp_rate', 'noncore', 'lev', 'stock_rate', 'indicator']
data_smote = sorted_data_rate[columns_to_keep]

missing_rows = data_smote[data_smote.isnull().any(axis=1)]

# dropping all the rows with na's 
data_smote = data_smote.dropna()

# standardizing the data
columns_to_standardize =  ['cpi_rate', 'rconsumption_rate', 'housing_rate', 'money_rate', 'DSR_rate', 'credit_rate',
                   'global_credit_rate', 'slope', 'global_slope','ca_rate',  'investment_rate',  'debtgdp_rate', 'noncore', 'lev', 'stock_rate']
scaler = StandardScaler()
data_smote[columns_to_standardize] = scaler.fit_transform(data_smote[columns_to_standardize])
data_smote
# Out:
#       cpi_rate  rconsumption_rate  housing_rate  money_rate  DSR_rate  \
# 449   0.201881          -0.360813     -0.652080   -0.436655  0.147522
# 463  -0.261516          -0.029319     -0.656442   -0.598620  0.147522
# 477  -0.821518           0.663119     -0.750580   -0.546395  0.147522
# 492  -0.403177          -0.216924     -0.575168   -0.279722  0.147522
# 508  -0.256875          -1.409564     -0.103857   -0.104969  0.147522
# ...        ...                ...           ...         ...       ...
# 1934 -0.288071          -0.135756     -0.098293   -0.183195  0.147522
# 1952 -0.211250          -0.123374     -0.061040   -0.246539  0.147522
# 1970 -0.185625           0.035701     -0.058903   -0.353630  0.147522
# 1988 -0.241482          -0.139349     -0.135576   -0.281110  0.147522
# 2006 -0.291768          -1.765667      0.052789    0.537220  0.147523
#
#       credit_rate    country  year  global_credit_rate     slope  \
# 449     -0.654988  Australia  1902           -0.129854 -0.194538
# 463      0.098263  Australia  1903           -0.224598 -0.181635
# 477     -0.622619  Australia  1904            1.196896 -0.051417
# 492     -0.318556  Australia  1905            0.258444 -0.174400
# 508     -0.586132  Australia  1906            0.382874 -0.343230
# ...           ...        ...   ...                 ...       ...
# 1934     0.211747        USA  2016           -0.640859  0.377931
# 1952    -0.154200        USA  2017           -0.917938  0.307137
# 1970    -0.333830        USA  2018           -1.077548  0.161669
# 1988    -0.124981        USA  2019           -0.367818 -0.475965
# 2006     1.075286        USA  2020            2.559247 -0.161754
#
#       global_slope   ca_rate  investment_rate  debtgdp_rate   noncore  \
# 449      -0.804990  0.061955         1.408468     -0.120645 -0.794071
# 463      -0.852109 -0.501147         0.201038      0.399111 -0.767489
# 477      -0.825305  2.247694        -2.502742     -0.341809 -0.728409
# 492      -1.372852  2.025113        -0.598677      0.105125 -0.698360
# 508      -2.197101  0.451962         0.278050     -0.368536 -0.706451
# ...            ...       ...              ...           ...       ...
# 1934      0.239300  0.021547        -0.146201      0.657504 -1.084357
# 1952      0.488379  0.084435         0.507329     -0.160241 -1.097936
# 1970      0.376195 -0.144460         0.234130      0.040609 -1.117756
# 1988     -0.334627 -0.059269         0.092718      0.126687 -1.150102
# 2006     -0.554474 -0.337244         0.241315      2.981622 -1.300048
#
#            lev  stock_rate  indicator
# 449   1.407139   -0.139900          0
# 463   1.417348    0.045137          0
# 477   1.266318   -0.145051          0
# 492   1.104951    0.582410          0
# 508   0.988934    0.112638          0
# ...        ...         ...        ...
# 1934  0.493013    0.005969          0
# 1952  0.509522    0.354953          0
# 1970  0.519181   -0.064077          0
# 1988  0.501606   -0.036528          0
# 2006  0.321268    0.071001          0
#
# [1057 rows x 18 columns]

# %%
country=list(set(data_smote.country))
# loop each country_Region and split the data into train and test data
X_train=[]
X_test=[]
Y_train=[]
Y_test=[]
for i in range(0,len(country)):
    df = data_smote[data_smote['country'] == country[i]]
    # applied the function I created above
    x_train, x_test,y_train,y_test=train_test_split(df)
    X_train.append(x_train)
    X_test.append(x_test)
    Y_train.append(y_train)
    Y_test.append(y_test)
# concatenate each train data n X_train list and Y_train list respectively
X_train=pd.concat(X_train)
Y_train=pd.DataFrame(pd.concat(Y_train))
# concatenate each test dataset in X_test list and Y_test list respectively
X_test=pd.concat(X_test)
Y_test=pd.DataFrame(pd.concat(Y_test))

X_test_dropped = X_test.drop(columns=['country', 'year'])
X_train_dropped = X_train.drop(columns=['country', 'year'])
Y_train_array = Y_train.values
Y_test_array = Y_test.values

# %%
# this will take a while to run

# Convert DataFrame to 1-dimensional array
Y_train_array = Y_train.values.ravel()


# Logistic Regression
logreg = LogisticRegression(penalty = 'none')
logreg.fit(X_train_dropped, Y_train_array)

# Predict probabilities for the test set
y_pred_prob_logreg = logreg.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC
fpr_logreg, tpr_logreg, thresholds_logreg = roc_curve(Y_test_array, y_pred_prob_logreg)
roc_auc_logreg = roc_auc_score(Y_test_array, y_pred_prob_logreg)

# Random Forest with hyperparameter tuning using cross-validation
rf = RandomForestClassifier()

# Perform cross-validation to tune hyperparameters
hyperparameters = {'n_estimators': [50, 100, 200],
                   'max_depth': [None, 10, 20]}

rf_cv = GridSearchCV(rf, hyperparameters, cv=5, scoring='roc_auc')
rf_cv.fit(X_train_dropped, Y_train_array)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_rf = rf_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_rf = best_rf.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC for random forest
fpr_rf, tpr_rf, thresholds_rf = roc_curve(Y_test_array, y_pred_prob_rf)
roc_auc_rf = roc_auc_score(Y_test_array, y_pred_prob_rf)

# lasso model

# Random Forest with hyperparameter tuning using cross-validation
lasso_logreg = LogisticRegression(penalty='l1', solver='liblinear')

# Define hyperparameters to tune
hyperparameters_lasso = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

# Perform cross-validation to tune hyperparameters
lasso_cv = GridSearchCV(lasso_logreg, hyperparameters_lasso, cv=5, scoring='roc_auc')
lasso_cv.fit(X_train_dropped, Y_train_array)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_lasso_logreg = lasso_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_lasso = best_lasso_logreg.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC
fpr_lasso, tpr_lasso, thresholds_lasso = roc_curve(Y_test_array, y_pred_prob_lasso)
roc_auc_lasso = roc_auc_score(Y_test_array, y_pred_prob_lasso)

#elastic net 

# ElasticNet model
elasticnet = ElasticNet()

# Define hyperparameters to tune
hyperparameters_elasticnet = {'alpha': [0.001, 0.01, 0.1, 1, 10],
                              'l1_ratio': [0.1, 0.5, 0.7, 0.9]}

# Perform cross-validation to tune hyperparameters
elasticnet_cv = GridSearchCV(elasticnet, hyperparameters_elasticnet, cv=5, scoring='roc_auc')
elasticnet_cv.fit(X_train_dropped, Y_train_array)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_elasticnet = elasticnet_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_elasticnet = best_elasticnet.predict(X_test_dropped)

# Compute ROC curve and AUC
fpr_elasticnet, tpr_elasticnet, _ = roc_curve(Y_test, y_pred_prob_elasticnet)
roc_auc_elasticnet = roc_auc_score(Y_test_array, y_pred_prob_elasticnet)


# gradient boosting 
gradientboost = GradientBoostingClassifier()

# Define hyperparameters to tune
hyperparameters_GB = {
    'n_estimators': [150, 200, 250],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01,0.03, 0.05, 0.07, 0.1]
}

# Perform cross-validation to tune hyperparameters
GB_cv = GridSearchCV(gradientboost, hyperparameters_GB, cv=5, scoring='roc_auc')
GB_cv.fit(X_train_dropped, Y_train_array)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_GB = GB_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_GB = best_GB.predict_proba(X_test_dropped)[:, 1]  # Assuming binary classification

# Compute ROC curve and AUC
fpr_GB, tpr_GB, _ = roc_curve(Y_test_array, y_pred_prob_GB)
roc_auc_GB = roc_auc_score(Y_test_array, y_pred_prob_GB)
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_logreg, tpr_logreg, color='black' ,label='Logistic Regression (AUC = {:.2f})'.format(roc_auc_logreg))
plt.plot(fpr_rf, tpr_rf,  color='purple',label='Random Forest (AUC = {:.2f})'.format(roc_auc_rf))
plt.plot(fpr_lasso, tpr_lasso, color='red', label='Lasso Model (AUC = {:.2f})'.format(roc_auc_lasso))
plt.plot(fpr_elasticnet, tpr_elasticnet,  color='green',label='Elastic Net Model (AUC = {:.2f})'.format(roc_auc_elasticnet))
plt.plot(fpr_GB, tpr_GB,  color='orange',label='Gradient Boosting Model (AUC = {:.2f})'.format(roc_auc_GB))

plt.plot(fpr_lstm, tpr_lstm, color='blue', label='LSTM (AUC = {:.2f})'.format(auc_neural))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Forecasting')
plt.legend(loc='lower right')
plt.axhline(0.8, linestyle='--',color = 'grey') #horizontal line

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# The chart above plots the performance of the models in the ROC space. The y-axis indicates the true positive rate, or intutively the 'hit rate'. The x-axis indicates the false positive rate, or 'false alarm rate'. The measure of performance are the models tradeoffs between true and false positive rates, with the area under the curve serving as a way to compare the different models.

# %% [markdown]
# The black line indicates the baseline logistic model. So we see all of our Lasso, Elastic Net, LSTM, Gradient Boosting, and Random Forest models perform better than the logsistic model. The LSTM performed the best out of all the models. To interpret this result, the LSTM can predict 80% of all crises before they occur while only incuring an 18% false alarm rate.

# %% [markdown]
# ## SMOTE Resampling to adjust for imbalanced data

# %% [markdown]
# The infrequency of financial crises does cause our data to be imbalanced. Thus, to ensure that our results are robust, we resample our data using the Synthetic Minority Oversampling Technique, or SMOTE for short. This method essentially employs a k-nearest neighbor approach and synthetic data is randomly generated from the minority class (observations of crisis).

# %%
from imblearn.over_sampling import SMOTE


# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_dropped, Y_train_array)

Y_train_array_flat = y_train_resampled.flatten()

# Convert the flattened array to a Pandas Series
Y_train_series = pd.Series(Y_train_array_flat)

# %% [markdown]
# ## Let's try this over again with a balanced dataset

# %%
# Logistic Regression
logreg = LogisticRegression(penalty = 'none')
logreg.fit(X_train_resampled, Y_train_series)

# Predict probabilities for the test set
y_pred_prob_logreg = logreg.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC
fpr_logreg, tpr_logreg, thresholds_logreg = roc_curve(Y_test_array, y_pred_prob_logreg)
roc_auc_logreg = roc_auc_score(Y_test_array, y_pred_prob_logreg)
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(

# %%
# Random Forest with hyperparameter tuning using cross-validation
rf = RandomForestClassifier()

# Perform cross-validation to tune hyperparameters
hyperparameters = {'n_estimators': [50, 100, 200],
                   'max_depth': [None, 10, 20]}

rf_cv = GridSearchCV(rf, hyperparameters, cv=5, scoring='roc_auc')
rf_cv.fit(X_train_resampled, Y_train_series)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_rf = rf_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_rf = best_rf.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC for random forest
fpr_rf, tpr_rf, thresholds_rf = roc_curve(Y_test_array, y_pred_prob_rf)
roc_auc_rf = roc_auc_score(Y_test_array, y_pred_prob_rf)

# %%
# lasso model

# Random Forest with hyperparameter tuning using cross-validation
lasso_logreg = LogisticRegression(penalty='l1', solver='liblinear')

# Define hyperparameters to tune
hyperparameters_lasso = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

# Perform cross-validation to tune hyperparameters
lasso_cv = GridSearchCV(lasso_logreg, hyperparameters_lasso, cv=5, scoring='roc_auc')
lasso_cv.fit(X_train_resampled, Y_train_series)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_lasso_logreg = lasso_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_lasso = best_lasso_logreg.predict_proba(X_test_dropped)[:, 1]

# Compute ROC curve and AUC
fpr_lasso, tpr_lasso, thresholds_lasso = roc_curve(Y_test_array, y_pred_prob_lasso)
roc_auc_lasso = roc_auc_score(Y_test_array, y_pred_prob_lasso)

# %%
#elastic net 

# ElasticNet model


elasticnet = LogisticRegression(solver="saga", penalty="elasticnet")

# Define hyperparameters to tune
hyperparameters_elasticnet = {'C': [0.001, 0.01, 0.1, 1, 10],
                              'l1_ratio': [0.1, 0.5, 0.7, 0.9]}

# Perform cross-validation to tune hyperparameters
elasticnet_cv = GridSearchCV(elasticnet, hyperparameters_elasticnet, cv=5, scoring='roc_auc')
elasticnet_cv.fit(X_train_resampled, Y_train_series)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_elasticnet = elasticnet_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_elasticnet = best_elasticnet.predict_proba(X_test_dropped)[:, 1]


# Compute ROC curve and AUC
fpr_elasticnet, tpr_elasticnet, _ = roc_curve(Y_test_array, y_pred_prob_elasticnet)
roc_auc_elasticnet = roc_auc_score(Y_test_array, y_pred_prob_elasticnet)
# Out:
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\sjten\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
# gradient boosting 
gradientboost = GradientBoostingClassifier()

# Define hyperparameters to tune
hyperparameters_GB = {
    'n_estimators': [150, 200, 250],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.01,0.03, 0.05, 0.07, 0.1]
}

# Perform cross-validation to tune hyperparameters
GB_cv = GridSearchCV(gradientboost, hyperparameters_GB, cv=5, scoring='roc_auc')
GB_cv.fit(X_train_resampled, Y_train_series)  # Use the 1-dimensional array

# Get the best model from cross-validation
best_GB = GB_cv.best_estimator_

# Predict probabilities for the test set
y_pred_prob_GB = best_GB.predict_proba(X_test_dropped)[:, 1]  # Assuming binary classification

# Compute ROC curve and AUC
fpr_GB, tpr_GB, _ = roc_curve(Y_test_array, y_pred_prob_GB)
roc_auc_GB = roc_auc_score(Y_test_array, y_pred_prob_GB)

# %%
# neural network
sorted_data_rate = data_rate.sort_values(by=['country', 'year'])
columns_to_keep = ['country', 'year' , 'credit_rate', 'housing_rate', 'global_slope','lev_rate', 'slope', 'stock_rate', 'global_credit_rate', 'indicator']
data_neural = sorted_data_rate[columns_to_keep]

missing_rows = data_neural[data_neural.isnull().any(axis=1)]

# dropping all the rows with na's 
data_neural = data_neural.dropna()

# standardizing the data
columns_to_standardize = ['credit_rate',  'housing_rate', 'global_slope', 'slope', 'stock_rate', 'lev_rate', 'global_credit_rate']
scaler = StandardScaler()
data_neural[columns_to_standardize] = scaler.fit_transform(data_neural[columns_to_standardize])
 

##################################################
train_data=data_neural.iloc[:int(len(data_neural)*0.7)] 
test_data=data_neural.iloc[int(len(data_neural)*0.7):]
########################################################3
country=list(set(data_neural.country))
# loop each country_Region and split the data into train and test data
X_train=[]
X_test=[]
Y_train=[]
Y_test=[]
for i in range(0,len(country)):
    df = data_neural[data_neural['country'] == country[i]]
    # applied the function I created above
    x_train, x_test,y_train,y_test=train_test_split(df)
    X_train.append(x_train)
    X_test.append(x_test)
    Y_train.append(y_train)
    Y_test.append(y_test)
# concatenate each train data n X_train list and Y_train list respectively
X_train=pd.concat(X_train)
Y_train=pd.DataFrame(pd.concat(Y_train))
# concatenate each test dataset in X_test list and Y_test list respectively
X_test=pd.concat(X_test)
Y_test=pd.DataFrame(pd.concat(Y_test))

X_train['country']= encoder.fit_transform(X_train['country'])

X_train_augment_resampled, y_train_augment_resampled = smote.fit_resample(X_train, Y_train)


####################################################3
encoder = LabelEncoder()
#combine X train and Y train as train data 
train_data=pd.DataFrame()
train_data[X_train.columns]=X_train_augment_resampled
train_data[Y_train.columns]=y_train_augment_resampled
train_data['country']= encoder.fit_transform(train_data['country'])
#combine X test and Y test as test data 
test_data=pd.DataFrame()
test_data[X_test.columns]=X_test
test_data[Y_test.columns]=Y_test
test_data['country']= encoder.fit_transform(test_data['country'])



# using the function to obtian reshaped data 
x_train,x_test,y_train,y_test=reshape_data(train_data,test_data)

x_train_augment = np.delete(x_train, [0, 1, 9, 10,11], axis=2)


x_test_augment =  np.delete(x_test, [0, 1, 9, 10,11], axis=2)
##########################################################
tf.random.set_seed(6)

# because of randomness of neural network, replication of results may require re-runs to see a 'good' result for in-sample AUC fit
model1 = Sequential()

# Add LSTM layer with L2 regularization
model1.add(LSTM(11, activation='sigmoid', input_shape=(x_train_augment.shape[1], x_train_augment.shape[2]),kernel_regularizer=regularizers.l2(0.1),  # Add L2 regularization with regularization strength 0.01
               recurrent_regularizer=regularizers.l2(0.1)))

model1.add(Dense(units = 1,activation='relu'))
model1.compile(loss='mse', optimizer='adam', metrics=['auc'])
history = model1.fit(x_train_augment, y_train, epochs=50, batch_size=16, verbose=1, shuffle=False)
# Out:
# Epoch 1/50
# C:\Users\sjten\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - auc: 0.3417 - loss: 2.8283
# Epoch 2/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.5707 - loss: 1.2176
# Epoch 3/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6052 - loss: 0.6263
# Epoch 4/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6164 - loss: 0.4043
# Epoch 5/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6231 - loss: 0.3252
# Epoch 6/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6284 - loss: 0.2983
# Epoch 7/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6321 - loss: 0.2891
# Epoch 8/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6359 - loss: 0.2857
# Epoch 9/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6388 - loss: 0.2843
# Epoch 10/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6406 - loss: 0.2837
# Epoch 11/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6421 - loss: 0.2835
# Epoch 12/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6430 - loss: 0.2833
# Epoch 13/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6446 - loss: 0.2832
# Epoch 14/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6447 - loss: 0.2832
# Epoch 15/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6450 - loss: 0.2832
# Epoch 16/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6454 - loss: 0.2831
# Epoch 17/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6455 - loss: 0.2831
# Epoch 18/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6460 - loss: 0.2831
# Epoch 19/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6465 - loss: 0.2831
# Epoch 20/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6474 - loss: 0.2830
# Epoch 21/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6473 - loss: 0.2830
# Epoch 22/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6476 - loss: 0.2830
# Epoch 23/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6480 - loss: 0.2830
# Epoch 24/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6482 - loss: 0.2829
# Epoch 25/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6483 - loss: 0.2829
# Epoch 26/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6488 - loss: 0.2828
# Epoch 27/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6494 - loss: 0.2828
# Epoch 28/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6496 - loss: 0.2827
# Epoch 29/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6496 - loss: 0.2827
# Epoch 30/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6499 - loss: 0.2826
# Epoch 31/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6502 - loss: 0.2826
# Epoch 32/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6508 - loss: 0.2825
# Epoch 33/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6509 - loss: 0.2825
# Epoch 34/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6514 - loss: 0.2824
# Epoch 35/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6515 - loss: 0.2823
# Epoch 36/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6519 - loss: 0.2823
# Epoch 37/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6517 - loss: 0.2822
# Epoch 38/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6519 - loss: 0.2822
# Epoch 39/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6522 - loss: 0.2821
# Epoch 40/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6532 - loss: 0.2821
# Epoch 41/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6534 - loss: 0.2820
# Epoch 42/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6538 - loss: 0.2819
# Epoch 43/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6541 - loss: 0.2819
# Epoch 44/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6545 - loss: 0.2818
# Epoch 45/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6544 - loss: 0.2818
# Epoch 46/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - auc: 0.6547 - loss: 0.2817
# Epoch 47/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6549 - loss: 0.2817
# Epoch 48/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6551 - loss: 0.2816
# Epoch 49/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6553 - loss: 0.2815
# Epoch 50/50
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - auc: 0.6555 - loss: 0.2815

# %%
# neural network continued

y_pred_prob_RNN=model1.predict(x_test_augment)


pa1=pd.DataFrame()
pa1['Prediction']=[i[0] for i in y_pred_prob_RNN][1:] 
pa1['Actual Values']=y_test[:-1]
pa1['Prediction1'] = pa1['Prediction'].apply(lambda x: 1 if x >= 0.19 else 0)

# Compute ROC curve and AUC
fpr_lstm, tpr_lstm, _ = roc_curve(y_test, y_pred_prob_RNN)
roc_auc_lstm = roc_auc_score(y_test, y_pred_prob_RNN)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_log_binary = np.where(y_pred_prob_logreg >= 0.5, 1, 0)
y_lasso_binary = np.where(y_pred_prob_lasso >= 0.5, 1, 0)
y_rf_binary = np.where(y_pred_prob_rf >= 0.4, 1, 0)
y_gb_binary = np.where(y_pred_prob_GB >= 0.45, 1, 0)
y_rnn_binary = np.where(y_pred_prob_RNN >= 0.45, 1, 0)

# %%
recall = f1_score(Y_test_array, y_log_binary)
recall2 = f1_score(Y_test_array, y_lasso_binary)
recall3 = f1_score(Y_test_array, y_rf_binary)
recall4 = f1_score(Y_test_array, y_gb_binary)
recall5 = f1_score(y_test, y_rnn_binary)

print("Logistic Model F1 Score:", recall)
print("Lasso F1 Score:", recall2)
print("Random Forest F1 Score:", recall3)
print("Gradient Boost F1 Score:", recall4)
print("LSTM RNN F1 Score:", recall5)
# Out:
# Logistic Model F1 Score: 0.34545454545454546
# Lasso F1 Score: 0.3471074380165289
# Random Forest F1 Score: 0.2711864406779661
# Gradient Boost F1 Score: 0.30769230769230765
# LSTM RNN F1 Score: 0.3153153153153153

# %% [markdown]
# Another metric to measure the out-of-sample classification ability is through the F1-Score, which serves as a tradeoff between the Recall and Precision rates. We see that the LSTM performs better on this metric than all the other models. Noticably, LASSO, Random Forest, and Gradient Boosting do not appear to perform better than the Logistic Model.

# %%
# Plot ROC curves 
plt.figure(figsize=(8, 6))
plt.plot(fpr_logreg, tpr_logreg,  color='black',label='Logistic Regression (AUC = {:.2f})'.format(roc_auc_logreg))
plt.plot(fpr_rf, tpr_rf,  color='purple',label='Random Forest (AUC = {:.2f})'.format(roc_auc_rf))
plt.plot(fpr_lasso, tpr_lasso,  color='red',label='Lasso Model (AUC = {:.2f})'.format(roc_auc_lasso))
plt.plot(fpr_elasticnet, tpr_elasticnet, label='Elastic Net Model (AUC = {:.2f})'.format(roc_auc_elasticnet))
plt.plot(fpr_GB, tpr_GB,  color='orange',label='Gradient Boosting Model (AUC = {:.2f})'.format(roc_auc_GB))

plt.plot(fpr_lstm, tpr_lstm, color='blue', label='LSTM (AUC = {:.2f})'.format(roc_auc_lstm))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Forecasting with SMOTE Sample')
plt.legend(loc='lower right')
plt.axhline(0.8, linestyle='--',color = 'grey') #horizontal line

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# Resampling the data provides comparable results from the original dataset. The Elastic Net, Lasso, LSTM, and Random Forest all perform better than the baseline logistic model. However, the gradient boosting model underperforms. While the LSTM model is not the best model now, which proper hyperparameter tuning it would likely have a better fit. Overall, these results help validate the findings from the original dataset.

# %% [markdown]
# # Shapley Values

# %% [markdown]
# One of the biggest drawbacks to using black box machine learning techniques is the inability to interpret variables within the models. To combat this issue, we use Shapley Values to delve deeper into the LSTM model.

# %%
x_train_2d = np.squeeze(x_train_augment, axis=1)

# %%
#this will take a while to run 

import shap
background_summary = shap.sample(x_train_2d, 30)

def model_predict(data):
    # Ensure data is in the expected shape
    data = np.expand_dims(data, axis=1)  # Add singleton dimension for time steps
    return model.predict(data).flatten()

# Initialize the KernelExplainer
explainer = shap.KernelExplainer(model_predict, background_summary)

# Calculate SHAP values
shap_values = explainer.shap_values(x_train_2d, nsamples=50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#   0%|          | 0/818 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step

# %%
shap.summary_plot(shap_values, features=x_train_2d, max_display=9)

# %% [markdown]
# Given the format of the data, feature values were not retained for the LSTM model and thus was not able to be included in the chart above. Feature 3 and 10 are Leverage, and the lagged version of Leverage. The Shapley Values indicate that the most important variable for the LSTM model slope of the yield curve. A low level, or inverted, yield curve is important for predicting financial crises.

# %% [markdown]
# The next important feature is Global Slope (Feature 3 and lagged version, Feature 11). Low values of Global Slope, which can be interpreted as a low or inverted global yield curve, is important for the prediction of financial crises.

# %% [markdown]
# Finally, the third and fourth most important features are the lagged version of the leverage ratio and the lagged version of domestic credit growth.  High rates of credit growth in the previous year predict financial crises. Additionally, high levels of the capital ratio predict financial crises. This is an interesting and counterintuitive result.

# %% [markdown]
# ## Shapley Value Dependencies

# %% [markdown]
# In this section we will explore how the Shapley Values look

# %%
# Plot SHAP dependence plot
shap.dependence_plot(9, shap_values, x_train_2d, interaction_index=9)

# %% [markdown]
# This plot shows the relative Leverage of the banking sector on x-axis, and the Shapley Value of the y-axis. Again, a lower Shapley Value means that observation was important for predicting a non-crisis. A high Shapley value suggests that observation was important for predicting a crisis

# %% [markdown]
# The relationship between the capital ratio (leverage) and its Shapley Value is nonlinear. This suggests that the capital ratio has a nonlinear relationship with predicting financial crises.

# %%
shap.dependence_plot(9, shap_values, x_train_2d, interaction_index=4)

# %% [markdown]
# Now the color in this plot represents the value of the domestic yield curve slope. We can see that low levels of the yield curve seem to increase the elasticity of the capital ratio. A low yield curve coupled with high rates of change in the capital ratio predict financial crisis.

# %%
# Plot SHAP dependence plot
shap.dependence_plot(4, shap_values, x_train_2d, interaction_index=4,xmin="percentile(1)", xmax="percentile(99)")

# %% [markdown]
# In this instance we are looking at the values and importance of the domestic slope of the yield curve. The relationship is once again not exactly linear.

# %%
shap.dependence_plot(3, shap_values, x_train_2d, interaction_index=3,xmin="percentile(1)", xmax="percentile(99)")

# %% [markdown]
# Here we are looking at the Shapley Values for the global slope of the yield curve. The relationship looks fairly linear.

# %%
shap.dependence_plot(8, shap_values, x_train_2d, interaction_index=3,xmin="percentile(1)", xmax="percentile(99)")

# %% [markdown]
# Here we are looking at the lag of domestic credit rate growth. The relationship appears to have some nonlinearities. The color in this plot is the value of the global slope of the yield curve. Thus, when the global slope of the yield curve is low (blue) the 'elasticity' of credit growth increases. In other words, high rates of credit growth paired with an inverted yield curve predict crisis.

# %%
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, x_train_2d)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iKRC988LFFOP7GO1FSF4P'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.05939935420950254, "link": "identity", "featureNames": ["Feature 0", "Feature 1", "Feature 2", "Feature 3", "Feature 4", "Feature 5", "Feature 6", "Feature 7", "Feature 8", "Feature 9", "Feature 10", "Feature 11", "Feature 12", "Feature 13", "Feature 14", "Feature 15"], "explanations": [{"outValue": 0.1063266322016716, "simIndex": 74.0, "features": {"0": {"effect": 0.002785464273416504, "value": 0.4341435281358007}, "1": {"effect": 0.0, "value": -0.897673398668183}, "2": {"effect": 0.0, "value": -0.1301263237414419}, "3": {"effect": 0.021183855834391974, "value": -1.168910452338348}, "4": {"effect": 0.029090930418953578, "value": -0.7099977567690584}, "5": {"effect": -0.0008778415874846515, "value": -1.1979804097007472}, "6": {"effect": -0.001525888919261674, "value": -0.03274710969187301}, "7": {"effect": 0.0, "value": 0.36764271738323206}, "8": {"effect": 0.004938309858348293, "value": 0.21511707651522952}, "9": {"effect": -0.01186570494208462, "value": -0.1961744047284254}, "10": {"effect": 0.0, "value": -0.4806121088194268}, "11": {"effect": 0.005658466092311986, "value": -0.6496930191681651}, "12": {"effect": 0.007582506166636261, "value": -0.7533192698197282}, "13": {"effect": -0.005727992772248766, "value": 0.8089089228330705}, "14": {"effect": -0.0017719589878911527, "value": -0.07413719745571025}, "15": {"effect": -0.0025428674429186643, "value": -0.0003217572654947143}}}, {"outValue": 0.11495202779769897, "simIndex": 206.0, "features": {"0": {"effect": 0.001789104734644526, "value": 0.21511707651522952}, "1": {"effect": 0.001131582433003153, "value": -0.1961744047284254}, "2": {"effect": -0.0043610679056763045, "value": -0.4806121088194268}, "3": {"effect": 0.008728540772125449, "value": -0.6496930191681651}, "4": {"effect": 0.03244081214504026, "value": -0.7533192698197282}, "5": {"effect": 0.003979963023944974, "value": 0.8089089228330705}, "6": {"effect": 0.0, "value": -0.07413719745571025}, "7": {"effect": -0.004162864774473713, "value": -0.0003217572654947143}, "8": {"effect": 0.0075384684834887755, "value": 0.2556464426042898}, "9": {"effect": -0.023656647443846785, "value": -0.5194864376785029}, "10": {"effect": 0.0, "value": -0.20877940085253846}, "11": {"effect": 0.00869561015571956, "value": -0.8881317485806822}, "12": {"effect": 0.008463222978702147, "value": -0.573012144812286}, "13": {"effect": 0.0181846305161217, "value": -1.5237432643071958}, "14": {"effect": -0.0013340913197008807, "value": 0.04457952197442067}, "15": {"effect": -0.0018845902108964308, "value": 0.08362770423966652}}}, {"outValue": 0.0938711166381836, "simIndex": 154.0, "features": {"0": {"effect": 0.0, "value": 0.2556464426042898}, "1": {"effect": 0.0017786797677146408, "value": -0.5194864376785029}, "2": {"effect": 0.0, "value": -0.20877940085253846}, "3": {"effect": 0.01101436291109756, "value": -0.8881317485806822}, "4": {"effect": 0.020401469208922038, "value": -0.573012144812286}, "5": {"effect": -0.0031818573673783653, "value": -1.5237432643071958}, "6": {"effect": 0.0, "value": 0.04457952197442067}, "7": {"effect": 0.0, "value": 0.08362770423966652}, "8": {"effect": 0.0021342049197951166, "value": 0.12219557735745022}, "9": {"effect": -0.016927228163725702, "value": -0.3964790275779373}, "10": {"effect": -0.002348757882413755, "value": -0.6104719018127848}, "11": {"effect": 0.01070886340448194, "value": -1.0417434966298724}, "12": {"effect": 0.006635110083937634, "value": -0.5412928300843823}, "13": {"effect": 0.010083570380846675, "value": -0.6588697606567764}, "14": {"effect": -0.002053018727938961, "value": -0.09207911750140586}, "15": {"effect": -0.003773636106657763, "value": -0.0015073099762178228}}}, {"outValue": 0.04935196042060852, "simIndex": 160.0, "features": {"0": {"effect": 0.0, "value": 0.12219557735745022}, "1": {"effect": 0.0014309371419727632, "value": -0.3964790275779373}, "2": {"effect": -0.00383484633994536 ...

# %% [markdown]
# This interactive plot uses Shapley Values to explain every single prediction made in our training set.

# %% [markdown]
# ## Can our Models predict the Great Financial Crisis?

# %%
test_data
# Out:
#       country  year  credit_rate       lev  housing_rate  global_slope  \
# 1416       12  1981     0.167184 -0.907932     -0.452228     -0.307090
# 1434       12  1982     0.179838 -0.902527     -0.355853      0.274614
# 1452       12  1983    -0.276061 -0.641808     -0.322982      0.020819
# 1470       12  1984    -0.174663 -0.649739     -0.140974     -0.026911
# 1487       12  1985    -0.112408 -0.619108     -0.153820     -0.511876
# ...       ...   ...          ...       ...           ...           ...
# 1917        0  2016     0.931483 -0.478538     -0.110065      0.277888
# 1935        0  2017    -0.825375 -0.377701      0.046861      0.525835
# 1953        0  2018    -0.277279 -0.378325     -0.493299      0.414160
# 1971        0  2019    -0.730171 -0.309602     -0.638367     -0.293431
# 1989        0  2020    -0.189275 -0.279839     -0.115781     -0.512280
#
#          slope  stock_rate  global_credit_rate  indicator
# 1416  0.566865    0.021164            0.017820          0
# 1434  1.246797   -0.029810           -0.301221          0
# 1452  0.168370    0.025548           -0.224140          0
# 1470 -0.113068   -0.078858           -0.027076          0
# 1487 -1.287632    0.032619            0.268157          0
# ...        ...         ...                 ...        ...
# 1917 -0.112445   -0.030763           -0.501915          0
# 1935  0.065757   -0.011267           -0.733441          0
# 1953  0.236114   -0.121350           -0.866809          0
# 1971 -0.279440   -1.124669           -0.273763          1
# 1989 -0.115060   -0.069268            2.172074          1
#
# [361 rows x 10 columns]

# %%
# find index for usa in 2006
test_data.index[(test_data['global_credit_rate'] > 1.298845) & (test_data['global_credit_rate'] < 1.298847) & (test_data['slope'] > -0.578310) & (test_data['slope'] < -0.578308)]
# Out:
# Index([1819], dtype='int64')

# %%
# checking our Y_test value for that year and country pair
Y_test.loc[[1819]]
# Out:
#       indicator
# 1819          1

# %%
test_data_reset = test_data.reset_index()
test_data_reset.index[(test_data_reset['global_credit_rate'] > 1.298845) & (test_data_reset['global_credit_rate'] < 1.298847) & (test_data_reset['slope'] > -0.578310) & (test_data_reset['slope'] < -0.578308)]
# Out:
# Index([302], dtype='int64')

# %%
pa.loc[300]
# Out:
# Prediction       0.126816
# Actual Values    1.000000
# Prediction1      0.000000
# Name: 300, dtype: float64

# %%
# percentiles 
percentiles = [85, 93, 94]

# Calculate percentiles using numpy.percentile
percentile_values = np.percentile(pa['Prediction'], percentiles)
percentile_values
# Out:
# array([0.14858958, 0.19733015, 0.20281132])

# %%
print("The mean probability of crisis for the LSTM:", y_test_pre.mean())
print("The standard deviation of probability of crisis for the LSTM:", (y_test_pre.std()))
print("The probability of crisis within two years in 2005 (USA):", pa['Prediction'].loc[300])
print("The probability of crisis within two years in 2006 (USA):", (pa['Prediction'].loc[301]))
# Out:
# The mean probability of crisis for the LSTM: 0.047981113
# The standard deviation of probability of crisis for the LSTM: 0.06629999
# The probability of crisis within two years in 2005 (USA): 0.081257
# The probability of crisis within two years in 2006 (USA): 0.049980164

# %% [markdown]
# The LSTM model shows elevated risk for financial crisis in the years of 2005 and 2006, with an elevated risk of 1.6 standard deviations above the average risk level. This probability of crisis occuring within the next two years in 2005 is above the 93rd percentile of risk levels produced by the model in the testing set. This model accurately predicts the 2008 financial crisis.

# %%
pa1.loc[300]
# Out:
# Prediction       0.479082
# Actual Values    1.000000
# Prediction1      1.000000
# Name: 300, dtype: float64

# %%
# percentiles 
percentiles = [84, 90, 95]

# Calculate percentiles using numpy.percentile
percentile_values = np.percentile(pa1['Prediction'], percentiles)
percentile_values
# Out:
# array([0.53774532, 0.57061158, 0.65752643])

# %%
print("The mean probability of crisis for the LSTM:", y_pred_prob_RNN.mean())
print("The standard deviation of probability of crisis for the LSTM:", (y_pred_prob_RNN.std()))
print("The probability of crisis within two years in 2005 (USA):", pa1['Prediction'].loc[300])
print("The probability of crisis within two years in 2006 (USA):", (pa1['Prediction'].loc[301]))
# Out:
# The mean probability of crisis for the LSTM: 0.43258035
# The standard deviation of probability of crisis for the LSTM: 0.11868385
# The probability of crisis within two years in 2005 (USA): 0.47908184
# The probability of crisis within two years in 2006 (USA): 0.43176544

# %% [markdown]
# Validating these results with the SMOTE sample, 2005 once again falls roughly 1.2 standard deviations above the average probability of crisis. 2005 for the USA ranks around the 85th percentile in crisis probability for the testing data. With the resampling method we still observe that the models forecasts elevated chance of crisis directly before the Great Financial Crisis.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Overall, machine learning techniques are able to predict financial crises with better efficiency than standard econometric approaches. This is an incredibly valuable tool for both policy-makers and investors alike. Policy-makers can shift monetary policy from re-active to pro-active using these early warning indicator models, and may be able to styme crisis and seriously limit contagion effects from nascent crises. For investors, knowing when to hedge against increased downside potential is incredibly valuable, and can prevent huge losses on portfolios in the event of crisis.

# %% [markdown]
# We find that many of the macroeconomic variable have a nonlinear relationship when it comes to predicting financial crisis. Thus machine learning techniques like nerual networks can be useful in this field. We find that the domestic and global slope of the yield curve are the most important variable for predicting financial crisis. We also find that the global slope of the yield curve can augment the relationship that credit growth has with predicting financial crises. In line with previous research, we find that a low or inverted global yield curve coupled with high rates of domestic credit growth is an important indicator of financial crisis.
